# %%
import UWGeodynamics as GEO
import numpy as np
from underworld import function as fn
import glucifer
from MechanicalProperties import PlateProperties
from ModelGeometry import SubductionCreator,interpolateTracer,rmRepeated,fuseListM,ListToNd
# Out:
# loaded rc file /usr/local/lib/python3.5/dist-packages/UWGeodynamics/uwgeo-data/uwgeodynamicsrc

# %%
#Units
u = GEO.UnitRegistry
#Rebecca et al., Scaling
dRho =   80. * u.kilogram / u.meter**3 # matprop.ref_density
g    =   9.8 * u.meter / u.second**2   # modprop.gravity
H    = 800. * u.kilometer #  modprop.boxHeight-- OR 840 dependig if I include the sticky air layer

# lithostatic pressure for mass-time-length
ref_stress = dRho * g * H
# viscosity of upper mante for mass-time-length
ref_viscosity = 1e20 * u.pascal * u.seconds
#References
ref_time        = ref_viscosity/ref_stress
ref_length      = H
ref_mass        = (ref_viscosity*ref_length*ref_time)
#ref_temperature = modprop.Tint - modprop.Tsurf

KL = ref_length       
KM = ref_mass         
Kt = ref_time
#KT = ref_temperature

GEO.scaling_coefficients["[length]"] = KL
GEO.scaling_coefficients["[time]"] = Kt
GEO.scaling_coefficients["[mass]"]= KM
#GEO.scaling_coefficients["[temperature]"] = KT

# %%
#Model Dimensions
Model = GEO.Model(elementRes=(296,160), #296,160 #296,128, #120,64
                  minCoord=(-1800. * u.kilometer, -800.0 * u.kilometer), 
                  maxCoord=(1800. * u.kilometer, 0.0 * u.kilometer),
                  gravity=(0.0, -9.81 * u.meter / u.second**2))

#Model Output Folder
Model.outputDir = "outputs_MechanicalTransference_BenchmarkFinal_32kmArc_80Ma_DruckerPrager_WLM"

# %%
#need to find an expression to calculate the length of decoupling layer in function of resolution....the minimum working
#value to quickly achieve subduction without overlubricate the subduction zone

# %%
#Model Geometry 
#Decoupling Layer- 70 Km for 296, for 120, 110
DipAngle=30
DipLen=300
#SubductionCreator(Model,y0,thickness, dipAngle, dipLength, maxLength, orientation, SLayers,OLayers, ExLens,bStrips,tD=False)
geometry=SubductionCreator(Model,0,100,DipAngle,DipLen,2400,-1,4,2,(210,210,210,210),(40,40,40,40),(True,True, True, True),0.)
xcoords = GEO.uw.function.input()[0]
ycoords = GEO.uw.function.input()[1]
#Model limits
orientation=geometry[6][0]
xlimit=GEO.nd(geometry[6][1])
#cratLim=GEO.nd(geometry[8][2])

# %%
#PlateProperties(Nlayers,crustThickness,crustDensity,mantleDensity,plateThickness,oceanic,age, cohesion,friction,arc,arcDensity,arcThickness,depthToMantle)
#Oceanic Plate
data1=PlateProperties(4,7.,2900.,3400.,100.,True,80.,12.5,12.5,0.066,0.033,False,0.,0.,100.,2.)
#Cratonic continental - Values can be +5MPa!!
data2=PlateProperties(2,40.,2700.,3400.,150.,False,80.,15.,10.,0.15,0.08,False,0.,0.,150.,.2)
#Back-arc
data3=PlateProperties(2,20.,2800.,3400.,100.,False,80.,10.,7.5,0.005,0.0035,False,0.,0.,80.,2.) #the last specifies how much was extended the lithosphere
#Arc Crust
data4=PlateProperties(4,7.,2900.,3400.,100.,True,80.,12.5,12.5,0.066,0.033,True,2838.,32.,100.,2.)
#eclogite-Properties
data5=PlateProperties(4,7.,3500.,3400.,100.,True,80.,12.5,12.5,0.066,0.033,False,0.,0.,100.,2.)
# Out:
# /usr/local/lib/python3.5/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)

# %%
#Densities without units 
refD=3400.0 * u.kilogram / u.metre**3 #Mantle Density
#(Subducting plate)
l1d=data1[2][0]* u.kilogram / u.metre**3 
l2d=data1[2][1]* u.kilogram / u.metre**3 
l3d=data1[2][2]* u.kilogram / u.metre**3 
l4d=data1[2][3]* u.kilogram / u.metre**3 
#Cratonic overriding plate
cl1=data2[2][0]* u.kilogram / u.metre**3 
cl2=data2[2][1]* u.kilogram / u.metre**3 
#Back-Arc overriding plate
bl1=data3[2][0]* u.kilogram / u.metre**3 
bl2=data3[2][1]* u.kilogram / u.metre**3 
#Arc density
al1=data4[2][0]* u.kilogram / u.metre**3 
al2=data4[2][1]* u.kilogram / u.metre**3 
#Oceanic crust to Eclogite
e1d=data5[2][0]* u.kilogram / u.metre**3
#Lower Mantle density - 1.6 +-1 to 5+-2 percentage the upper mantle density - (1.6+7)/2/100 - 3400.+(3400*0.043)
LMdensity=3546.2* u.kilogram / u.metre**3

# %%
## Calculate Geometry
#SubductionCreator(Model,y0,thickness, dipAngle, dipLength, maxLength, orientation, SLayers,OLayers, ExLens,bStrips,tD=False)
#return subducting,overriding, weak,arc,bstop
#Materials in the model
#stickyAir=Model.add_material(name="StickyAir", shape=GEO.shapes.Layer(top=40.*u.kilometer, bottom=0.*u.kilometer))
UMantle =Model.add_material(name="UpperMantle", shape=GEO.shapes.Layer(top=0.*u.kilometer, bottom=-660.*u.kilometer))
#stickyAir = Model.add_material(name="Air", shape=GEO.shapes.Layer(top=Model.top, bottom=0. * u.kilometer))
LMantle=Model.add_material(name="LowerMantle", shape=GEO.shapes.Layer(top=-660.*u.kilometer, bottom=Model.bottom))
#OLithosphere1D = Model.add_material(name="SubductingPlateL1", shape=geometry[0][0][0])
#OLithosphere2D=Model.add_material(name="SubductingPlateL2", shape=geometry[0][0][1])
#OLithosphere3D=Model.add_material(name="SubductingPlateL3", shape=geometry[0][0][2])
#OLithosphere4D=Model.add_material(name="SubductingPlateL4", shape=geometry[0][0][3])
OLithosphere1F = Model.add_material(name="SubductingPlateL1", shape=geometry[0][2][0])
OLithosphere2F=Model.add_material(name="SubductingPlateL2", shape=geometry[0][2][1])
OLithosphere3F=Model.add_material(name="SubductingPlateL3", shape=geometry[0][2][2])
OLithosphere4F=Model.add_material(name="SubductingPlateL4", shape=geometry[0][2][3])
Clithosphere1= Model.add_material(name="Overriding plate Crust", shape=geometry[1][0])
Clithosphere2= Model.add_material(name="Overriding plate Lithosphere", shape=geometry[1][1])
Clithosphereweak1=Model.add_material(name="Overriding plate Weak Crust", shape=geometry[2][0])
Clithosphereweak2=Model.add_material(name="Overriding plate Weak Lithosphere", shape=geometry[2][1])
# decoup1= Model.add_material(name="Decoupling", shape=geometry[4][0])
# decoup2= Model.add_material(name="Decoupling", shape=geometry[4][1])
# decoup3= Model.add_material(name="Decoupling", shape=geometry[4][2])
# decoup4= Model.add_material(name="Decoupling", shape=geometry[4][3])
#backstop1=Model.add_material(name="Back Stop", shape=geometry[4][0])
#backstop2=Model.add_material(name="Back Stop", shape=geometry[4][1])
#backstop3=Model.add_material(name="Back Stop", shape=geometry[4][2])
#backstop4=Model.add_material(name="Back Stop", shape=geometry[4][3])
OArc1=Model.add_material(name="IntraOceanicArc", shape=geometry[3][0])
OArc2=Model.add_material(name="IntraOceanicArc", shape=geometry[3][1])
# sg11=Model.add_material(name="Weakness1", shape=geometry[5][0])
# sg12=Model.add_material(name="Weakness2", shape=geometry[5][1])
# sg13=Model.add_material(name="Weakness3", shape=geometry[5][2])
# sg14=Model.add_material(name="Weakness4", shape=geometry[5][3])

# %%
# #Eclogite material
# eclogite=Model.add_material(name="EclogiteTrans")
# #Orogenic wedge material
# #Owedge=Model.add_material(name="Orogen Material"))

# %%
#Preview of 2D materials-Materials Field (from swarm)
Fig = glucifer.Figure(figsize=(1200,400))
Fig.Points(Model.swarm, Model.materialField,fn_size=2.0, discrete=True)
#Fig.Surface(Model.mesh,Model.projMaterialField,fn_size=2.0)
Fig.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
#Lateral Change in density or not in this model.
LateralChange=False
if LateralChange==True:
    fac=1.
else:
    fac=0.

#Parameters
if orientation==1:
    SPdelta = (GEO.nd(Model.maxCoord[0])-(GEO.nd(xlimit)) - (GEO.nd(100 * u.kilometer)))
elif orientation==-1:
    SPdelta = (GEO.nd(Model.minCoord[0])-(GEO.nd(xlimit)) + (GEO.nd(100 * u.kilometer)))
#Conditions for both orientations

if orientation==1:
    c5="xcoords < xlimit"
elif orientation==-1:
    c5="xcoords > xlimit"
#If orientation =1
conditionsL=[(geometry[0][1][0],(fac*(GEO.nd((refD-l1d))/SPdelta)*(fn.math.abs(GEO.nd(xcoords-(xlimit)))))+GEO.nd(l1d)),
            (geometry[0][1][1],(fac*(GEO.nd((refD-l2d))/SPdelta)*(fn.math.abs(GEO.nd(xcoords-(xlimit)))))+GEO.nd(l2d)),
            (geometry[0][1][2],(fac*(GEO.nd((refD-l3d))/SPdelta)*(fn.math.abs(GEO.nd(xcoords-(xlimit)))))+GEO.nd(l3d)),
            (geometry[0][1][3],(fac*(GEO.nd((refD-l4d))/SPdelta)*(fn.math.abs(GEO.nd(xcoords-(xlimit)))))+GEO.nd(l4d)),
            (geometry[0][0][0],GEO.nd(l1d)),
            (geometry[0][0][1],(GEO.nd((l2d)))),
            (geometry[0][0][2],(GEO.nd((l3d)))),
            (geometry[0][0][3],(GEO.nd((l4d)))),
             (Model.y > GEO.nd(-660.*u.kilometer),GEO.nd(refD)),
            (True,GEO.nd(LMdensity))]

#If orientation =-1

conditionsR=[(geometry[0][1][0],(fac*(GEO.nd((refD-l1d))/SPdelta)*((GEO.nd(xcoords-(xlimit)))))+GEO.nd(l1d)),
            (geometry[0][1][1],(fac*(GEO.nd((refD-l2d))/SPdelta)*((GEO.nd(xcoords-(xlimit)))))+GEO.nd(l2d)),
            (geometry[0][1][2],(fac*(GEO.nd((refD-l3d))/SPdelta)*((GEO.nd(xcoords-(xlimit)))))+GEO.nd(l3d)),
            (geometry[0][1][3],(fac*(GEO.nd((refD-l4d))/SPdelta)*((GEO.nd(xcoords-(xlimit)))))+GEO.nd(l4d)),
            (geometry[0][0][0],GEO.nd(l1d)),
            (geometry[0][0][1],(GEO.nd((l2d)))),
            (geometry[0][0][2],(GEO.nd((l3d)))),
            (geometry[0][0][3],(GEO.nd((l4d)))),
            (Model.y > GEO.nd(-660.*u.kilometer),GEO.nd(refD)),
            (True,GEO.nd(LMdensity))]

if orientation==1:
    conditionsD=conditionsL
elif orientation==-1:
    conditionsD=conditionsR


RoFn =  fn.branching.conditional(conditionsD)
RoField=GEO.uw.swarm.SwarmVariable(Model.swarm,dataType="double",count=1)
RoField.data[:]=RoFn.evaluate(Model.swarm)

# %%
#Eclogitization parametrization
conditions=[(Model.y > GEO.nd(-150.*u.kilometer),RoField),
            (True,GEO.nd(e1d)),
    
]
eclogiteFn=fn.branching.conditional(conditions)

# %% [raw]
# #Lower Mantle average density (from Jeanloz and ..)
# #Olivine-Ringwoodite to perovskite- Transition upper-lower mantle
# conditionsT=[(Model.y > GEO.nd(-660.*u.kilometer),GEO.nd(LMdensity)),
#              (True,GEO.nd(refD)),
#
# ]
# mantleTransitionFn=fn.branching.conditional(conditionsT)

# %%
## Density- Includes relative density calculation for arc
#stickyAir.density = 100. * u.kilogram / u.metre**3
UMantle.density = RoField
LMantle.density = RoField 
OLithosphere1F.density =eclogiteFn
OLithosphere2F.density =RoField
OLithosphere3F.density =RoField
OLithosphere4F.density =RoField
Clithosphere1.density=cl1  
Clithosphere2.density=cl2
Clithosphereweak1.density=bl1 
Clithosphereweak2.density=bl2
OArc1.density=al1 
OArc2.density=al2

# %%
#Density Field
Fig = glucifer.Figure(figsize=(1200,400))
#Fig.Points(Model.swarm, GEO.Dimensionalize(Model.densityField, u.kilogram / u.metre**3))
Fig.Surface(Model.mesh, GEO.Dimensionalize(Model.projDensityField, u.kilogram / u.metre**3))
Fig.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/UWGeodynamics/__init__.py:83: UserWarning: 'Dimensionalize' has been changed to 'dimensionalise', please use the later
#   warnings.warn("""'Dimensionalize' has been changed to 'dimensionalise', please use the later""")
# <img src='data:image/png;base64,...'>

# %%
#Viscosities without units 
refV=1e20 #UMantle as reference Viscosity
#(Subducting plate)
vl1d=data1[3][0]
vl2d=data1[3][1]
vl3d=data1[3][2]
vl4d=data1[3][3]
#Cratonic overriding plate
vcl1=data2[3][0]
vcl2=data2[3][1]
#Back-Arc overriding plate
vbl1=data3[3][0]
vbl2=data3[3][1]
#Arc viscosity -- Consider what discussed in Len & Gurnis, 2015 (lower-middle crust is very weak)
val1=data4[3][0]
val2=data4[3][1]
# #Eclogite viscosity
# ve1=data5[3][0]

# %%
#stickyAir.viscosity=1e19 * u.pascal * u.second
Model.minViscosity=refV * u.pascal * u.second
UMantle.viscosity =  refV * u.pascal * u.second#UMantle as reference Viscosity
LMantle.viscosity =  30*refV* u.pascal * u.second
#OLithosphere1D.viscosity = 1e5*refV * u.pascal * u.second
#OLithosphere2D.viscosity = 1e5*refV* u.pascal * u.second
#OLithosphere3D.viscosity = 1.93*10**(4)*refV* u.pascal * u.second
#OLithosphere4D.viscosity = 9.64*10**(1)*refV* u.pascal * u.second
OLithosphere1F.viscosity = vl1d* u.pascal * u.second
OLithosphere2F.viscosity = vl2d* u.pascal * u.second
OLithosphere3F.viscosity = vl3d* u.pascal * u.second
OLithosphere4F.viscosity = vl4d* u.pascal * u.second
Clithosphere1.viscosity= vcl1 * u.pascal * u.second
Clithosphere2.viscosity= vcl2 *u.pascal * u.second
Clithosphereweak1.viscosity= vbl1 * u.pascal * u.second
Clithosphereweak2.viscosity= vbl2* u.pascal * u.second#
# decoup1.viscosity= 10**(0)*vbl1 * u.pascal * u.second
# decoup2.viscosity= 10**(0)*vbl1* u.pascal * u.second #
# decoup3.viscosity= 10**(0)*vbl2* u.pascal * u.second #
# decoup4.viscosity= 10**(0)*vbl2* u.pascal * u.second 
#backstop1.viscosity=1e25* u.pascal * u.second
#backstop2.viscosity=1e25* u.pascal * u.second
#backstop3.viscosity=1e25* u.pascal * u.second
#backstop4.viscosity=1e25* u.pascal * u.second
# sg11.viscosity= 10**(-2)*vl1d* u.pascal * u.second
# sg12.viscosity= 10**(-2)*vl2d* u.pascal * u.second
# sg13.viscosity=10**(-2)*vl3d* u.pascal * u.second
# sg14.viscosity=10**(-1)*vl4d* u.pascal * u.second
OArc1.viscosity= val1 * u.pascal * u.second
OArc2.viscosity= val2* u.pascal * u.second 
# eclogite.viscosity=refV *(10**(2))* u.pascal * u.second

# %%
#MinViscosity for materials
OLithosphere1F.minViscosity =10**(21) * u.pascal * u.second
OLithosphere2F.minViscosity = 10**(21) * u.pascal * u.second
OLithosphere3F.minViscosity = 10**(21) * u.pascal * u.second
OLithosphere4F.minViscosity = 10**(21) * u.pascal * u.second
Clithosphereweak1.minViscosity= 10**(21) * u.pascal * u.second
Clithosphereweak2.minViscosity=10**(21) * u.pascal * u.second

# %% [raw]
# GEO.extract_profile()

# %%
#Viscosity Field
Fig = glucifer.Figure(figsize=(1200,400))
Fig.Points(Model.swarm, GEO.Dimensionalize(Model.viscosityField, u.pascal * u.second),logScale=True)
Fig.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
#Plasticity- Mechanical Strength
weakSP=True #4,5,6,7 -(4,5) (6,7)
weakOP=True
#(Subducting plate)
if weakSP==True:
    pl1d=(data1[6][0],data1[7][0])
    pl2d=(data1[6][1],data1[7][1])
    pl3d=(data1[6][2],data1[7][2])
    pl4d=(data1[6][3],data1[7][3])
else:
    pl1d=(data1[4][0],data1[7][0])
    pl2d=(data1[4][1],data1[7][1])
    pl3d=(data1[4][2],data1[7][2])
    pl4d=(data1[4][3],data1[7][3])
#Cratonic overriding plate
if weakOP==True:
    pcl1=(data2[4][0],data2[5][0])
    pcl2=(data2[4][1],data2[5][1])
else:
    pcl1=(data2[4][0],data2[5][0])
    pcl2=(data2[4][1],data2[5][1])
#Back-Arc overriding plate
if weakOP==True:
    pbl1=(data3[4][0],data3[5][0])
    pbl2=(data3[4][1],data3[5][1])
else:
    pbl1=(data3[6][0],data3[7][0])
    pbl2=(data3[6][1],data3[7][1])
#Arc Plasticity -- Consider what discussed in Len & Gurnis, 2015 (lower-middle crust is very weak)
if weakSP==True:
    pal1=(data4[6][0],data4[7][0])
    pal2=(data4[6][1],data4[7][1])
else:
    pal1=(data4[4][0],data4[5][0])
    pal2=(data4[4][1],data4[5][1])

# %% [raw]
# # Drucker-Prager-DS2-1600 length-150 width arc-This is the one that works better!-Limit of viscosity
# OLithosphere1F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.004,
#                                               #cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.0001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# OLithosphere2F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                               frictionCoefficient=0.004,
#                                               cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.0027, #to 0.0035 ? from 0.0027
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# OLithosphere3F.plasticity =GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                              frictionCoefficient= 0.006,
#                                              cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                              frictionAfterSoftening=0.0042,
#                                             epsilon1=0.0,
#                                             epsilon2=0.2)
# # OLithosphere4F.plasticity =GEO.VonMises(cohesion=pl4d[0] * u.megapascal,
# #                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)
# Clithosphere1.plasticity =GEO.DruckerPrager(cohesion=15. * u.megapascal,  #Mean from Lower and Upper from Rey et al., 2014
#                                             frictionCoefficient=0.08,
#                                        cohesionAfterSoftening=15./2. * u.megapascal,
#                                        frictionAfterSoftening=0.05,
#                                             epsilon1=0.0, epsilon2=0.2)
# Clithosphere2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal,
#                                              frictionCoefficient=0.08, #Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=5. * u.megapascal,
#                                        frictionAfterSoftening=0.05,
#                                              epsilon1=0.0, epsilon2=0.2)
# Clithosphereweak1.plasticity = GEO.DruckerPrager(cohesion=15. * u.megapascal,
#                                                  frictionCoefficient=0.045,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=7.5 * u.megapascal,
#                                                  frictionAfterSoftening=0.00001,
#                                                  epsilon1=0.0, epsilon2=0.2)
# Clithosphereweak2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal,
#                                                  frictionCoefficient=0.0055,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=5. * u.megapascal,
#                                                  frictionAfterSoftening=0.0015,
#                                                 epsilon1=0.0, epsilon2=0.2)   #Friction to zero due to weakening (Patrice personal and Len & Gurnis, 2015)
# OArc1.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.004,
#                                               cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.20)
# OArc2.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.004,
#                                               cohesionAfterSoftening=12.5/6. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.20)
# # decoup1.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.001,
# #                                                  epsilon1=0.0, epsilon2=0.01)
# # decoup2.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.001,
# #                                                  epsilon1=0.0, epsilon2=0.01)
# # decoup3.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.002,
# #                                                 epsilon1=0.0, epsilon2=0.01)
# # decoup4.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.002,
# #                                                 epsilon1=0.0, epsilon2=0.01)
# # sg11.plasticity = GEO.VonMises(cohesion=pal1[0]/4. * u.megapascal,
# #                                               cohesionAfterSoftening=pal1[1] * u.megapascal,
# #                                              epsilon1=0.0,
# #                                              epsilon2=0.2)
# # sg12.plasticity = GEO.VonMises(cohesion=pal2[0]/4. * u.megapascal,
# #                                               cohesionAfterSoftening=pal2[1] * u.megapascal,
# #                                              epsilon1=0.0,
# #                                              epsilon2=0.2)
# # sg13.plasticity =GEO.VonMises(cohesion=pl3d[0]/4. * u.megapascal,
# #                                              cohesionAfterSoftening=pl3d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)
# # sg14.plasticity =GEO.VonMises(cohesion=pl4d[0]/4. * u.megapascal,
# #                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)

# %% [raw]
# # Drucker-Prager- 35 km - Phase
# OLithosphere1F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.004,
#                                               #cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.0025, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# OLithosphere2F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                               frictionCoefficient=0.004,
#                                               cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.0025, #to 0.0035 ? from 0.0027
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# OLithosphere3F.plasticity =GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                              frictionCoefficient= 0.006,
#                                              cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                              frictionAfterSoftening=0.003,
#                                             epsilon1=0.0,
#                                             epsilon2=0.2)
# # OLithosphere4F.plasticity =GEO.VonMises(cohesion=pl4d[0] * u.megapascal,
# #                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)
# Clithosphere1.plasticity =GEO.DruckerPrager(cohesion=15. * u.megapascal,  #Mean from Lower and Upper from Rey et al., 2014
#                                             frictionCoefficient=0.08,
#                                        cohesionAfterSoftening=15./2. * u.megapascal,
#                                        frictionAfterSoftening=0.05,
#                                             epsilon1=0.0, epsilon2=0.2)
# Clithosphere2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal,
#                                              frictionCoefficient=0.08, #Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=5. * u.megapascal,
#                                        frictionAfterSoftening=0.05,
#                                              epsilon1=0.0, epsilon2=0.2)
# Clithosphereweak1.plasticity = GEO.DruckerPrager(cohesion=15. * u.megapascal,
#                                                  frictionCoefficient=0.045,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=7.5 * u.megapascal,
#                                                  frictionAfterSoftening=0.00001,
#                                                  epsilon1=0.0, epsilon2=0.2)
# Clithosphereweak2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal,
#                                                  frictionCoefficient=0.0055,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=5. * u.megapascal,
#                                                  frictionAfterSoftening=0.0015,
#                                                 epsilon1=0.0, epsilon2=0.2)   #Friction to zero due to weakening (Patrice personal and Len & Gurnis, 2015)
# OArc1.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.004,
#                                               cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.20)
# OArc2.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.004,
#                                               cohesionAfterSoftening=12.5/6. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.20)
# # decoup1.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.001,
# #                                                  epsilon1=0.0, epsilon2=0.01)
# # decoup2.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.001,
# #                                                  epsilon1=0.0, epsilon2=0.01)
# # decoup3.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.002,
# #                                                 epsilon1=0.0, epsilon2=0.01)
# # decoup4.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.002,
# #                                                 epsilon1=0.0, epsilon2=0.01)
# # sg11.plasticity = GEO.VonMises(cohesion=pal1[0]/4. * u.megapascal,
# #                                               cohesionAfterSoftening=pal1[1] * u.megapascal,
# #                                              epsilon1=0.0,
# #                                              epsilon2=0.2)
# # sg12.plasticity = GEO.VonMises(cohesion=pal2[0]/4. * u.megapascal,
# #                                               cohesionAfterSoftening=pal2[1] * u.megapascal,
# #                                              epsilon1=0.0,
# #                                              epsilon2=0.2)
# # sg13.plasticity =GEO.VonMises(cohesion=pl3d[0]/4. * u.megapascal,
# #                                              cohesionAfterSoftening=pl3d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)
# # sg14.plasticity =GEO.VonMises(cohesion=pl4d[0]/4. * u.megapascal,
# #                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)

# %% [raw]
# # Drucker-Prager-
# OLithosphere1F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.008,
#                                               #cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# OLithosphere2F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                               frictionCoefficient=0.008,
#                                               cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.0045, #to 0.0035 ? from 0.0027
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# OLithosphere3F.plasticity =GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                              frictionCoefficient= 0.01,
#                                              cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                              frictionAfterSoftening=0.0065,
#                                             epsilon1=0.0,
#                                             epsilon2=0.2)
# # OLithosphere4F.plasticity =GEO.VonMises(cohesion=pl4d[0] * u.megapascal,
# #                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)
# Clithosphere1.plasticity =GEO.DruckerPrager(cohesion=15. * u.megapascal,  #Mean from Lower and Upper from Rey et al., 2014
#                                             frictionCoefficient=0.08,
#                                        cohesionAfterSoftening=15./2. * u.megapascal,
#                                        frictionAfterSoftening=0.05,
#                                             epsilon1=0.0, epsilon2=0.2)
# Clithosphere2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal,
#                                              frictionCoefficient=0.08, #Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=5. * u.megapascal,
#                                        frictionAfterSoftening=0.05,
#                                              epsilon1=0.0, epsilon2=0.2)
# Clithosphereweak1.plasticity = GEO.DruckerPrager(cohesion=15. * u.megapascal,
#                                                  frictionCoefficient=0.0055,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=4. * u.megapascal,
#                                                  frictionAfterSoftening=0.00001,
#                                                  epsilon1=0.0, epsilon2=0.2)
# Clithosphereweak2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal,
#                                                  frictionCoefficient=0.0045,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=3.5 * u.megapascal,
#                                                  frictionAfterSoftening=0.0015,
#                                                 epsilon1=0.0, epsilon2=0.2)   #Friction to zero due to weakening (Patrice personal and Len & Gurnis, 2015)
# OArc1.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.008,
#                                               #cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.20)
# OArc2.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.008,
#                                               cohesionAfterSoftening=12.5/4. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.20)
# # decoup1.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.001,
# #                                                  epsilon1=0.0, epsilon2=0.01)
# # decoup2.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.001,
# #                                                  epsilon1=0.0, epsilon2=0.01)
# # decoup3.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.002,
# #                                                 epsilon1=0.0, epsilon2=0.01)
# # decoup4.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.002,
# #                                                 epsilon1=0.0, epsilon2=0.01)
# # sg11.plasticity = GEO.VonMises(cohesion=pal1[0]/4. * u.megapascal,
# #                                               cohesionAfterSoftening=pal1[1] * u.megapascal,
# #                                              epsilon1=0.0,
# #                                              epsilon2=0.2)
# # sg12.plasticity = GEO.VonMises(cohesion=pal2[0]/4. * u.megapascal,
# #                                               cohesionAfterSoftening=pal2[1] * u.megapascal,
# #                                              epsilon1=0.0,
# #                                              epsilon2=0.2)
# # sg13.plasticity =GEO.VonMises(cohesion=pl3d[0]/4. * u.megapascal,
# #                                              cohesionAfterSoftening=pl3d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)
# # sg14.plasticity =GEO.VonMises(cohesion=pl4d[0]/4. * u.megapascal,
# #                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)

# %% [raw]
# # Drucker-Prager-original in 20 Nov of 2019
# OLithosphere1F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.008,
#                                               #cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# OLithosphere2F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                               frictionCoefficient=0.008,
#                                               cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.0045, #to 0.0035 ? from 0.0027
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# OLithosphere3F.plasticity =GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                              frictionCoefficient= 0.01,
#                                              cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                              frictionAfterSoftening=0.0065,
#                                             epsilon1=0.0,
#                                             epsilon2=0.2)
# # OLithosphere4F.plasticity =GEO.VonMises(cohesion=pl4d[0] * u.megapascal,
# #                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)
# Clithosphere1.plasticity =GEO.DruckerPrager(cohesion=15. * u.megapascal,  #Mean from Lower and Upper from Rey et al., 2014
#                                             frictionCoefficient=0.08,
#                                        cohesionAfterSoftening=15./2. * u.megapascal,
#                                        frictionAfterSoftening=0.05,
#                                             epsilon1=0.0, epsilon2=0.2)
# Clithosphere2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal,
#                                              frictionCoefficient=0.08, #Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=5. * u.megapascal,
#                                        frictionAfterSoftening=0.05,
#                                              epsilon1=0.0, epsilon2=0.2)
# Clithosphereweak1.plasticity = GEO.DruckerPrager(cohesion=15. * u.megapascal,
#                                                  frictionCoefficient=0.0055,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=4. * u.megapascal,
#                                                  frictionAfterSoftening=0.00001,
#                                                  epsilon1=0.0, epsilon2=0.2)
# Clithosphereweak2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal,
#                                                  frictionCoefficient=0.0045,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=3.5 * u.megapascal,
#                                                  frictionAfterSoftening=0.0015,
#                                                 epsilon1=0.0, epsilon2=0.2)   #Friction to zero due to weakening (Patrice personal and Len & Gurnis, 2015)
# OArc1.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.008,
#                                               #cohesionAfterSoftening=12.5/2. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.20)
# OArc2.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
#                                             frictionCoefficient=0.008,
#                                               cohesionAfterSoftening=12.5/4. * u.megapascal,
#                                               frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
#                                              epsilon1=0.0,
#                                              epsilon2=0.20)
# # decoup1.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.001,
# #                                                  epsilon1=0.0, epsilon2=0.01)
# # decoup2.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.001,
# #                                                  epsilon1=0.0, epsilon2=0.01)
# # decoup3.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.002,
# #                                                 epsilon1=0.0, epsilon2=0.01)
# # decoup4.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal,
# #                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
# #                                        cohesionAfterSoftening=0.6 * u.megapascal,
# #                                                  #frictionAfterSoftening=0.002,
# #                                                 epsilon1=0.0, epsilon2=0.01)
# # sg11.plasticity = GEO.VonMises(cohesion=pal1[0]/4. * u.megapascal,
# #                                               cohesionAfterSoftening=pal1[1] * u.megapascal,
# #                                              epsilon1=0.0,
# #                                              epsilon2=0.2)
# # sg12.plasticity = GEO.VonMises(cohesion=pal2[0]/4. * u.megapascal,
# #                                               cohesionAfterSoftening=pal2[1] * u.megapascal,
# #                                              epsilon1=0.0,
# #                                              epsilon2=0.2)
# # sg13.plasticity =GEO.VonMises(cohesion=pl3d[0]/4. * u.megapascal,
# #                                              cohesionAfterSoftening=pl3d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)
# # sg14.plasticity =GEO.VonMises(cohesion=pl4d[0]/4. * u.megapascal,
# #                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
# #                                             epsilon1=0.0,
# #                                             epsilon2=0.2)

# %%
# Drucker-Prager-
OLithosphere1F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
                                            frictionCoefficient=0.008,
                                              #cohesionAfterSoftening=12.5/2. * u.megapascal,
                                              frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
                                             epsilon1=0.0, 
                                             epsilon2=0.2)
OLithosphere2F.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
                                              frictionCoefficient=0.008,
                                              cohesionAfterSoftening=12.5/2. * u.megapascal,
                                              frictionAfterSoftening=0.0045, #to 0.0035 ? from 0.0027
                                             epsilon1=0.0,
                                             epsilon2=0.2)
OLithosphere3F.plasticity =GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
                                             frictionCoefficient= 0.01,
                                             cohesionAfterSoftening=12.5/2. * u.megapascal,
                                             frictionAfterSoftening=0.0065,
                                            epsilon1=0.0,
                                            epsilon2=0.2)
# OLithosphere4F.plasticity =GEO.VonMises(cohesion=pl4d[0] * u.megapascal,
#                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
#                                             epsilon1=0.0,
#                                             epsilon2=0.2)
Clithosphere1.plasticity =GEO.DruckerPrager(cohesion=15. * u.megapascal,  #Mean from Lower and Upper from Rey et al., 2014
                                            frictionCoefficient=0.08,
                                       cohesionAfterSoftening=15./2. * u.megapascal, 
                                       frictionAfterSoftening=0.05,
                                            epsilon1=0.0, epsilon2=0.2)
Clithosphere2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal, 
                                             frictionCoefficient=0.08, #Mean from Lower and Upper from Rey et al., 2014
                                       cohesionAfterSoftening=5. * u.megapascal, 
                                       frictionAfterSoftening=0.05, 
                                             epsilon1=0.0, epsilon2=0.2)
Clithosphereweak1.plasticity = GEO.DruckerPrager(cohesion=15. * u.megapascal,
                                                 frictionCoefficient=0.0055,#Mean from Lower and Upper from Rey et al., 2014
                                       cohesionAfterSoftening=4. * u.megapascal,
                                                 frictionAfterSoftening=0.00001,
                                                 epsilon1=0.0, epsilon2=0.2)
Clithosphereweak2.plasticity = GEO.DruckerPrager(cohesion=10. * u.megapascal, 
                                                 frictionCoefficient=0.0045,#Mean from Lower and Upper from Rey et al., 2014
                                       cohesionAfterSoftening=3.5 * u.megapascal, 
                                                 frictionAfterSoftening=0.0015,
                                                epsilon1=0.0, epsilon2=0.2)   #Friction to zero due to weakening (Patrice personal and Len & Gurnis, 2015)    
OArc1.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
                                            frictionCoefficient=0.008,
                                              #cohesionAfterSoftening=12.5/2. * u.megapascal,
                                              frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
                                             epsilon1=0.0,
                                             epsilon2=0.20)
OArc2.plasticity = GEO.DruckerPrager(cohesion=12.5 * u.megapascal,
                                            frictionCoefficient=0.008,
                                              cohesionAfterSoftening=12.5/6. * u.megapascal,
                                              frictionAfterSoftening=0.00001, #Serpentinization (shallow 25 Km)
                                             epsilon1=0.0,
                                             epsilon2=0.20)
# decoup1.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
#                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=0.6 * u.megapascal,
#                                                  #frictionAfterSoftening=0.001,
#                                                  epsilon1=0.0, epsilon2=0.01)
# decoup2.plasticity=GEO.DruckerPrager(cohesion=10/4. * u.megapascal,
#                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=0.6 * u.megapascal,
#                                                  #frictionAfterSoftening=0.001,
#                                                  epsilon1=0.0, epsilon2=0.01)
# decoup3.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal, 
#                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=0.6 * u.megapascal, 
#                                                  #frictionAfterSoftening=0.002,
#                                                 epsilon1=0.0, epsilon2=0.01)   
# decoup4.plasticity= GEO.DruckerPrager(cohesion=7.5/4. * u.megapascal, 
#                                                  frictionCoefficient=0.0,#Mean from Lower and Upper from Rey et al., 2014
#                                        cohesionAfterSoftening=0.6 * u.megapascal, 
#                                                  #frictionAfterSoftening=0.002,
#                                                 epsilon1=0.0, epsilon2=0.01)  
# sg11.plasticity = GEO.VonMises(cohesion=pal1[0]/4. * u.megapascal,
#                                               cohesionAfterSoftening=pal1[1] * u.megapascal,
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# sg12.plasticity = GEO.VonMises(cohesion=pal2[0]/4. * u.megapascal,
#                                               cohesionAfterSoftening=pal2[1] * u.megapascal,
#                                              epsilon1=0.0,
#                                              epsilon2=0.2)
# sg13.plasticity =GEO.VonMises(cohesion=pl3d[0]/4. * u.megapascal,
#                                              cohesionAfterSoftening=pl3d[1] * u.megapascal,
#                                             epsilon1=0.0,
#                                             epsilon2=0.2)
# sg14.plasticity =GEO.VonMises(cohesion=pl4d[0]/4. * u.megapascal,
#                                              cohesionAfterSoftening=pl4d[1] * u.megapascal,
#                                             epsilon1=0.0,
#                                             epsilon2=0.2)

# %%
# #Passive Tracers- To track plate convergence/retreat rates
SPTracersC=rmRepeated(geometry[7])
OPTracersC=rmRepeated(geometry[8])
ArcTracersC=rmRepeated(geometry[9])
CratonTracersC=rmRepeated(geometry[10])
#Map for vertexes
SPMap=[(0,1),(1,2),(5,4),(4,3),(8,7),(7,6),(11,10),(10,9),(14,13),(13,12)]
# FlatMap=[(0,1),(5,4),(8,7),(11,10),(14,13)]
# DipMap=[(1,2),(4,3),(7,6),(10,9),(13,12)]
OPMap=[(0,1),(2,3),(4,5)]
ArcMap=[(0,1),(2,3),(4,5)]
CratMap=[(0,1),(2,3),(4,5)]

SP=[]
wise=0
for i in SPMap:
    if wise==0:
        npoints=500
        wise=1
    else:
        npoints=100
    aux=i
    SP.append(interpolateTracer([SPTracersC[0][aux[0]],SPTracersC[1][aux[0]]],
                         
                         [SPTracersC[0][aux[1]],SPTracersC[1][aux[1]]],400)) 
OP=[]
aux=OPMap[0]
OP.append(interpolateTracer([OPTracersC[0][aux[0]],OPTracersC[1][aux[0]]],
                         
                         [OPTracersC[0][aux[1]],OPTracersC[1][aux[1]]],400))
aux=OPMap[1]
OP.append(interpolateTracer([OPTracersC[0][aux[0]],OPTracersC[1][aux[0]]],
                         
                         [OPTracersC[0][aux[1]],OPTracersC[1][aux[1]]],400))
aux=OPMap[2]
OP.append(interpolateTracer([OPTracersC[0][aux[0]],OPTracersC[1][aux[0]]],
                         
                         [OPTracersC[0][aux[1]],OPTracersC[1][aux[1]]],400))
OP_Crat=[]
aux=CratMap[0]
OP_Crat.append(interpolateTracer([CratonTracersC[0][aux[0]],CratonTracersC[1][aux[0]]],
                         
                         [CratonTracersC[0][aux[1]],CratonTracersC[1][aux[1]]],400))
aux=CratMap[1]
OP_Crat.append(interpolateTracer([CratonTracersC[0][aux[0]],CratonTracersC[1][aux[0]]],
                         
                         [CratonTracersC[0][aux[1]],CratonTracersC[1][aux[1]]],400))
aux=CratMap[2]
OP_Crat.append(interpolateTracer([CratonTracersC[0][aux[0]],CratonTracersC[1][aux[0]]],
                         
                         [CratonTracersC[0][aux[1]],CratonTracersC[1][aux[1]]],400))

ArcT=[]
aux=ArcMap[0]
ArcT.append(interpolateTracer([ArcTracersC[0][aux[0]],ArcTracersC[1][aux[0]]],
                         
                         [ArcTracersC[0][aux[1]],ArcTracersC[1][aux[1]]],200))
aux=ArcMap[1]
ArcT.append(interpolateTracer([ArcTracersC[0][aux[0]],ArcTracersC[1][aux[0]]],
                         
                         [ArcTracersC[0][aux[1]],ArcTracersC[1][aux[1]]],200))

aux=ArcMap[2]
ArcT.append(interpolateTracer([ArcTracersC[0][aux[0]],ArcTracersC[1][aux[0]]],
                         
                         [ArcTracersC[0][aux[1]],ArcTracersC[1][aux[1]]],200))
#Fusing Data
# SP_F=fuseListM([SP_F[0],SP_F[1],SP_F[2],SP_F[3],SP_F[4]])
SP=fuseListM([SP[0],SP[1],SP[2],SP[3],SP[4],SP[5],SP[6],SP[7]])
OP=fuseListM([OP[0],OP[1],OP[2]])
ArcT=fuseListM([ArcT[0],ArcT[1],ArcT[2]])
CratonT=fuseListM([OP_Crat[0],OP_Crat[1],OP_Crat[2]])

# %%
# SP_FlatTracers = Model.add_passive_tracers(name="SPTracers_flat",vertices=[ListToNd(SP_F[0]),ListToNd(SP_F[1])])
SPTracers = Model.add_passive_tracers(name="SPTracers",vertices=[ListToNd(SP[0]),ListToNd(SP[1])])
OPTracers = Model.add_passive_tracers(name="OPTracers",vertices=[ListToNd(OP[0]),ListToNd(OP[1])])
ArcTracers= Model.add_passive_tracers(name="ArcTracers",vertices=[ListToNd((ArcT[0])),ListToNd((ArcT[1]))])
CratonTracers=Model.add_passive_tracers(name="CratonTracers",vertices=[ListToNd((CratonT[0])),ListToNd((CratonT[1]))])

# %%
Fig = glucifer.Figure(figsize=(1200,400))
Fig.Points(SPTracers, pointSize=5.0)
Fig.Points(OPTracers, pointSize=5.0)
Fig.Points(ArcTracers, pointSize=5.0)
Fig.Points(CratonTracers, pointSize=5.0)
Fig.Points(Model.swarm, Model.materialField, fn_size=3.0)
Fig.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
#Fields to Record
#Fields to Record

SPTracers.add_tracked_field(Model.velocityField[0],
                              name="Subducting plate velocity_X",
                              units=u.centimeter/ u.year,
                              dataType="float")
SPTracers.add_tracked_field(Model.velocityField[1],
                              name="Subducting plate velocity_Y",
                              units=u.centimeter/ u.year,
                              dataType="float")
ArcTracers.add_tracked_field(Model.velocityField[0],
                              name="Arc nodes velocity_X",
                              units=u.centimeter/ u.year,
                              dataType="float")
ArcTracers.add_tracked_field(Model.velocityField[1],
                              name="Arc nodes velocity_Y",
                              units=u.centimeter/ u.year,
                              dataType="float")
ArcTracers.add_tracked_field(Model.projStressTensor[0],
                              name="Arc stress tensor_X",
                              units=u.megapascal,
                              dataType="float")
ArcTracers.add_tracked_field(Model.projStressTensor[1],
                              name="Arc stress tensor_Y",
                              units=u.megapascal,
                              dataType="float")
ArcTracers.add_tracked_field(Model.projStressTensor[2],
                              name="Arc stress tensor_XY",
                              units=u.megapascal,
                              dataType="float")
ArcTracers.add_tracked_field(Model.strainRateField,
                              name="arc overriding plate strain rate",
                              units=u.megapascal,
                              dataType="float")
ArcTracers.add_tracked_field(Model.projStressField[0],
                              name="arc overriding plate stress Field",
                              units=u.megapascal,
                              dataType="float")
OPTracers.add_tracked_field(Model.velocityField[0],
                              name="Weak overriding plate velocity_X",
                              units=u.centimeter/ u.year,
                              dataType="float")
OPTracers.add_tracked_field(Model.velocityField[1],
                              name="Weak overriding plate velocity_Y",
                              units=u.centimeter/ u.year,
                              dataType="float")
OPTracers.add_tracked_field(Model.strainRateField,
                              name="Weak overriding plate strain rate",
                              units=u.megapascal,
                              dataType="float")
OPTracers.add_tracked_field(Model.projStressField[0],
                              name="Weak overriding plate stress Field",
                              units=u.megapascal,
                              dataType="float")
# OPTracers.add_tracked_field(Model.projStressField[1],
#                               name="Weak overriding plate stress Field_Y",
#                               units=u.megapascal,
#                               dataType="float")
# OPTracers.add_tracked_field(Model.projStressField[3],
#                               name="Weak overriding plate stress Field_XY",
#                               units=u.megapascal,
#                               dataType="float")
OPTracers.add_tracked_field(Model.projStressTensor[0],
                              name="Weak overriding plate stress tensor_X",
                              units=u.megapascal,
                              dataType="float")
OPTracers.add_tracked_field(Model.projStressTensor[1],
                              name="Weak overriding plate stress tensor_Y",
                              units=u.megapascal,
                              dataType="float")
OPTracers.add_tracked_field(Model.projStressTensor[2],
                              name="Weak overriding plate stress tensor_XY",
                              units=u.megapascal,
                              dataType="float")
SPTracers.add_tracked_field(Model.projTimeField,
                              name="Time_SP",
                              units=u.megayear,
                              dataType="float")
OPTracers.add_tracked_field(Model.projTimeField,
                              name="Time_OP",
                              units=u.megayear,
                              dataType="float")
CratonTracers.add_tracked_field(Model.projTimeField,
                              name="Time_SP",
                              units=u.megayear,
                              dataType="float")
CratonTracers.add_tracked_field(Model.velocityField[0],
                              name="Cratonic overriding plate velocity_X",
                              units=u.centimeter/ u.year,
                              dataType="float")
CratonTracers.add_tracked_field(Model.velocityField[1],
                              name="Cratonic overriding plate velocity_Y",
                              units=u.centimeter/ u.year,
                              dataType="float")
CratonTracers.add_tracked_field(Model.projStressTensor[0],
                              name="Craton stress tensor_X",
                              units=u.megapascal,
                              dataType="float")
CratonTracers.add_tracked_field(Model.projStressTensor[1],
                              name="Craton stress tensor_Y",
                              units=u.megapascal,
                              dataType="float")
CratonTracers.add_tracked_field(Model.projStressTensor[2],
                              name="Craton stress tensor_XY",
                              units=u.megapascal,
                              dataType="float")
ArcTracers.add_tracked_field(Model.projTimeField,
                              name="Time_Arc",
                              units=u.megayear,
                              dataType="float")

# %% [raw]
# #Eclogitization function
#
#
# def changeDensityFn(materialVar,densityValue):
#     densityValue=GEO.nd(densityValue)
#     obj=Model.y < GEO.nd(-150.*u.kilometer)
#     mask=obj.evaluate(Model.swarm)
#     conds = ((mask == 1) &(Model.materialField.data == materialVar.index))
#
#     Model.densityField.data[conds]=densityValue
#     Model._update()
#     return 1

# %% [raw]
# for material in self.materials:
#         if material.phase_changes:
#             for change in material.phase_changes:
#                 obj = change
#                 mask = obj.fn().evaluate(self.swarm)
#                 conds = ((mask == 1) &(self.materialField.data == material.index))
#                 self.materialField.data[conds] = obj.result

# %% [raw]
# #Ensure plastic damage effect on viscosity is preserved after phase transition
# # def updateFields(OLithosphere1F,e1d):
# #     changeDensityFn(OLithosphere1F,e1d)
# #     #Model._update()
# #     #_isYielding = Model._viscosity_processor._isYielding
# #     #plasticStrainIncrement = dt * _isYielding.evaluate(Model.swarm)
# #     #Model.plasticStrain.data[:] += plasticStrainIncrement
# # #     Model.viscosityField.data[...] = Model._viscosityFn.evaluate(Model.swarm)
# # #     Model._viscosityFieldProjector.solve()
# #     return 0
#
# Model.pre_solve_functions["changeDensityFn(OLithosphere1F,e1d)"] = changeDensityFn

# %%
#Free-slip Boundary Conditions (Kinematic BCs)
Model.set_velocityBCs(left=[0., None],
                     right=[0.,None],
                     bottom=[0., 0.],
                     top=[None, 0.])

# %%
#Free-Surface
#Model.freeSurface = True

# %%
Model.init_model()

# %%
#Solver Parameters
Model.solver.set_inner_method("lu")
Model.solver.set_penalty(1e6)
GEO.rcParams["initial.nonlinear.tolerance"] = 1e-4

# %%
#Data to Save
outputss=['temperature',
        'pressureField',
         'strainRateField',
         'velocityField',
          'projStressField',
          'projTimeField',
           'projMaterialField',
         'projViscosityField',
         'projStressField',
         'projMeltField',
          'projPlasticStrain',
         'projDensityField',
         'projStressTensor',
         ]
GEO.rcParams['default.outputs']=outputss

# %%
#Running Model
#!rm -rf output_FirstSubduction/
#Model.run_for(duration=40*u.megayear,checkpoint_interval=0.1*u.megayear,restartStep=-1,restartDir=Model.outputDir)
Model.run_for(duration=100*u.megayear,checkpoint_interval=0.5*u.megayear)
#Model.run_for(nstep=10, checkpoint_interval=0.1*u.megayear,restartStep=False)
# Out:
# Running with UWGeodynamics version 2.8.5
# Options:  -ksp_k2_type NULL -rescale_equations False -ksp_type bsscr -pc_type none -change_A11rhspresolve False -Q22_pc_type gkgdiag -change_backsolve False -force_correction True -restore_K False -remove_constant_pressure_null_space False -A11_pc_type lu -A11_ksp_type preonly -scr_ksp_rtol 1e-05 -scr_ksp_type fgmres -A11_mg_active False
# Step:     1 Model Time: 233875.2 year dt: 233875.2 year (2020-02-19 01:30:28)
# Step:     2 Model Time: 459651.2 year dt: 225776.0 year (2020-02-19 01:30:56)
# Step:     3 Model Time: 500000.0 year dt: 40348.8 year (2020-02-19 01:32:19)
# Step:     4 Model Time: 701285.8 year dt: 201285.8 year (2020-02-19 01:32:44)
# Step:     5 Model Time: 893659.9 year dt: 192374.2 year (2020-02-19 01:33:16)
# Step:     6 Model Time: 1.0 megayear dt: 106340.1 year (2020-02-19 01:34:51)
# Step:     7 Model Time: 1.2 megayear dt: 170797.3 year (2020-02-19 01:35:20)
# Step:     8 Model Time: 1.3 megayear dt: 156997.5 year (2020-02-19 01:36:04)
# Step:     9 Model Time: 1.5 megayear dt: 148449.3 year (2020-02-19 01:36:59)
# Step:    10 Model Time: 1.5 megayear dt: 23755.9 year (2020-02-19 01:38:36)
# Step:    11 Model Time: 1.6 megayear dt: 133373.3 year (2020-02-19 01:38:59)
# Step:    12 Model Time: 1.8 megayear dt: 118402.1 year (2020-02-19 01:40:10)
# Step:    13 Model Time: 1.9 megayear dt: 112333.6 year (2020-02-19 01:40:43)
# Step:    14 Model Time: 2.0 megayear dt: 105392.7 year (2020-02-19 01:41:21)
# Step:    15 Model Time: 2.0 megayear dt: 30498.4 year (2020-02-19 01:42:45)
# Step:    16 Model Time: 2.1 megayear dt: 99408.6 year (2020-02-19 01:43:08)
# Step:    17 Model Time: 2.2 megayear dt: 91953.5 year (2020-02-19 01:43:42)
# Step:    18 Model Time: 2.3 megayear dt: 87277.3 year (2020-02-19 01:44:16)
# Step:    19 Model Time: 2.4 megayear dt: 84338.4 year (2020-02-19 01:44:39)
# Step:    20 Model Time: 2.4 megayear dt: 78339.2 year (2020-02-19 01:45:18)
# Step:    21 Model Time: 2.5 megayear dt: 58683.0 year (2020-02-19 01:46:31)
# Step:    22 Model Time: 2.6 megayear dt: 71372.4 year (2020-02-19 01:46:55)
# Step:    23 Model Time: 2.6 megayear dt: 67959.6 year (2020-02-19 01:47:28)
# Step:    24 Model Time: 2.7 megayear dt: 65861.7 year (2020-02-19 01:47:51)
# Step:    25 Model Time: 2.8 megayear dt: 64668.2 year (2020-02-19 01:48:14)
# Step:    26 Model Time: 2.8 megayear dt: 61953.8 year (2020-02-19 01:48:43)
# Step:    27 Model Time: 2.9 megayear dt: 60142.7 year (2020-02-19 01:49:06)
# Step:    28 Model Time: 2.9 megayear dt: 57381.6 year (2020-02-19 01:49:29)
# Step:    29 Model Time: 3.0 megayear dt: 50660.0 year (2020-02-19 01:50:37)
# Step:    30 Model Time: 3.1 megayear dt: 53022.2 year (2020-02-19 01:51:01)
# Step:    31 Model Time: 3.1 megayear dt: 51116.2 year (2020-02-19 01:51:23)
# Step:    32 Model Time: 3.2 megayear dt: 50075.5 year (2020-02-19 01:51:47)
# Step:    33 Model Time: 3.2 megayear dt: 49027.2 year (2020-02-19 01:52:10)
# Step:    34 Model Time: 3.3 megayear dt: 47648.5 year (2020-02-19 01:52:33)
# Step:    35 Model Time: 3.3 megayear dt: 46768.6 year (2020-02-19 01:52:56)
# Step:    36 Model Time: 3.3 megayear dt: 46023.8 year (2020-02-19 01:53:20)
# Step:    37 Model Time: 3.4 megayear dt: 45421.0 year (2020-02-19 01:53:43)
# Step:    38 Model Time: 3.4 megayear dt: 44789.7 year (2020-02-19 01:54:08)
# Step:    39 Model Time: 3.5 megayear dt: 43875.5 year (2020-02-19 01:54:34)
# Step:    40 Model Time: 3.5 megayear dt: 22231.7 year (2020-02-19 01:55:47)
# Step:    41 Model Time: 3.5 megayear dt: 41433.4 year (2020-02-19 01:56:10)
# Step:    42 Model Time: 3.6 megayear dt: 40593.2 year (2020-02-19 01:56:34)
# Step:    43 Model Time: 3.6 megayear dt: 40636.9 year (2020-02-19 01:56:57)
# Step:    44 Model Time: 3.7 megayear dt: 40063.6 year (2020-02-19 01:57:20)
# Step:    45 Model Time: 3.7 megayear dt: 39343.0 year (2020-02-19 01:57:43)
# Step:    46 Model Time: 3.7 megayear dt: 38477.7 year (2020-02-19 01:58:06)
# Step:    47 Model Time: 3.8 megayear dt: 37893.9 year (2020-02-19 01:58:30)
# Step:    48 Model Time: 3.8 megayear dt: 37411.9 year (2020-02-19 01:58:53)
# Step:    49 Model Time: 3.9 megayear dt: 36333.5 year (2020-02-19 01:59:17)
# Step:    50 Model Time: 3.9 megayear dt: 35886.5 year (2020-02-19 01:59:40)
# Step:    51 Model Time: 3.9 megayear dt: 34895.0 year (2020-02-19 02:00:02)
# Step:    52 Model Time: 4.0 megayear dt: 35121.3 year (2020-02-19 02:00:26)
# Step:    53 Model Time: 4.0 megayear dt: 34617.9 year (2020-02-19 02:00:49)
# Step:    54 Model Time: 4.0 megayear dt: 7292.3 year (2020-02-19 02:01:57)
# Step:    55 Model Time: 4.0 megayear dt: 33983.3 year (2020-02-19 02:02:21)
# Step:    56 Model Time: 4.1 megayear dt: 33752.3 year (2020-02-19 02:02:44)
# Step:    57 Model Time: 4.1 megayear dt: 33396.3 year (2020-02-19 02:03:07)
# Step:    58 Model Time: 4.1 megayear dt: 33331.8 year (2020-02-19 02:03:30)
# Step:    59 Model Time: 4.2 megayear dt: 32730.6 year (2020-02-19 02:03:54)
# Step:    60 Model Time: 4.2 megayear dt: 32265.5 year (2020-02-19 02:04:17)
# Step:    61 Model Time: 4.2 megayear dt: 32675.0 year (2020-02-19 02:04:40)
# Step:    62 Model Time: 4.3 megayear dt: 32601.4 year (2020-02-19 02:05:03)
# Step:    63 Model Time: 4.3 megayear dt: 32448.0 year (2020-02-19 02:05:29)
# Step:    64 Model Time: 4.3 megayear dt: 32022.3 year (2020-02-19 02:05:53)
# Step:    65 Model Time: 4.4 megayear dt: 31595.9 year (2020-02-19 02:06:16)
# Step:    66 Model Time: 4.4 megayear dt: 31159.8 year (2020-02-19 02:06:39)
# Step:    67 Model Time: 4.4 megayear dt: 31024.3 year (2020-02-19 02:07:03)
# Step:    68 Model Time: 4.5 megayear dt: 30340.9 year (2020-02-19 02:07:26)
# Step:    69 Model Time: 4.5 megayear dt: 30271.4 year (2020-02-19 02:07:49)
# Step:    70 Model Time: 4.5 megayear dt: 16401.1 year (2020-02-19 02:08:59)
# Step:    71 Model Time: 4.5 megayear dt: 29889.6 year (2020-02-19 02:09:22)
# Step:    72 Model Time: 4.6 megayear dt: 29632.4 year (2020-02-19 02:09:45)
# Step:    73 Model Time: 4.6 megayear dt: 29246.9 year (2020-02-19 02:10:08)
# Step:    74 Model Time: 4.6 megayear dt: 29124.6 year (2020-02-19 02:10:31)
# Step:    75 Model Time: 4.6 megayear dt: 28780.5 year (2020-02-19 02:10:54)
# Step:    76 Model Time: 4.7 megayear dt: 28849.2 year (2020-02-19 02:11:16)
# Step:    77 Model Time: 4.7 megayear dt: 28986.8 year (2020-02-19 02:11:39)
# Step:    78 Model Time: 4.7 megayear dt: 28998.6 year (2020-02-19 02:12:02)
# Step:    79 Model Time: 4.8 megayear dt: 28572.1 year (2020-02-19 02:12:26)
# Step:    80 Model Time: 4.8 megayear dt: 28672.0 year (2020-02-19 02:12:49)
# Step:    81 Model Time: 4.8 megayear dt: 28761.5 year (2020-02-19 02:13:12)
# Step:    82 Model Time: 4.8 megayear dt: 28690.7 year (2020-02-19 02:13:35)
# Step:    83 Model Time: 4.9 megayear dt: 28616.8 year (2020-02-19 02:13:59)
# Step:    84 Model Time: 4.9 megayear dt: 28326.2 year (2020-02-19 02:14:22)
# Step:    85 Model Time: 4.9 megayear dt: 28227.2 year (2020-02-19 02:14:45)
# Step:    86 Model Time: 5.0 megayear dt: 27853.2 year (2020-02-19 02:15:08)
# Step:    87 Model Time: 5.0 megayear dt: 27807.4 year (2020-02-19 02:15:31)
# Step:    88 Model Time: 5.0 megayear dt: 10964.0 year (2020-02-19 02:16:40)
# Step:    89 Model Time: 5.0 megayear dt: 27536.4 year (2020-02-19 02:17:03)
# Step:    90 Model Time: 5.1 megayear dt: 27560.2 year (2020-02-19 02:17:26)
# Step:    91 Model Time: 5.1 megayear dt: 27283.3 year (2020-02-19 02:17:48)
# Step:    92 Model Time: 5.1 megayear dt: 27386.9 year (2020-02-19 02:18:11)
# Step:    93 Model Time: 5.1 megayear dt: 26929.0 year (2020-02-19 02:18:35)
# Step:    94 Model Time: 5.2 megayear dt: 26995.0 year (2020-02-19 02:18:58)
# Step:    95 Model Time: 5.2 megayear dt: 26988.1 year (2020-02-19 02:19:21)
# Step:    96 Model Time: 5.2 megayear dt: 26722.9 year (2020-02-19 02:19:44)
# Step:    97 Model Time: 5.2 megayear dt: 26604.4 year (2020-02-19 02:20:07)
# Step:    98 Model Time: 5.3 megayear dt: 26737.4 year (2020-02-19 02:20:30)
# Step:    99 Model Time: 5.3 megayear dt: 26335.6 year (2020-02-19 02:20:53)
# Step:   100 Model Time: 5.3 megayear dt: 26328.7 year (2020-02-19 02:21:16)
# Step:   101 Model Time: 5.3 megayear dt: 26469.3 year (2020-02-19 02:21:39)
# Step:   102 Model Time: 5.4 megayear dt: 26865.2 year (2020-02-19 02:22:02)
# Step:   103 Model Time: 5.4 megayear dt: 26257.1 year (2020-02-19 02:22:25)
# Step:   104 Model Time: 5.4 megayear dt: 26238.2 year (2020-02-19 02:22:48)
# Step:   105 Model Time: 5.5 megayear dt: 25928.8 year (2020-02-19 02:23:11)
# Step:   106 Model Time: 5.5 megayear dt: 25645.9 year (2020-02-19 02:23:34)
# Step:   107 Model Time: 5.5 megayear dt: 19187.5 year (2020-02-19 02:24:44)
# Step:   108 Model Time: 5.5 megayear dt: 25973.1 year (2020-02-19 02:25:07)
# Step:   109 Model Time: 5.6 megayear dt: 25781.2 year (2020-02-19 02:25:30)
# Step:   110 Model Time: 5.6 megayear dt: 25411.1 year (2020-02-19 02:25:53)
# Step:   111 Model Time: 5.6 megayear dt: 25362.7 year (2020-02-19 02:26:16)
# Step:   112 Model Time: 5.6 megayear dt: 25130.8 year (2020-02-19 02:26:39)
# Step:   113 Model Time: 5.7 megayear dt: 25365.7 year (2020-02-19 02:27:02)
# Step:   114 Model Time: 5.7 megayear dt: 25166.4 year (2020-02-19 02:27:26)
# Step:   115 Model Time: 5.7 megayear dt: 25323.8 year (2020-02-19 02:27:49)
# Step:   116 Model Time: 5.7 megayear dt: 25573.8 year (2020-02-19 02:28:12)
# Step:   117 Model Time: 5.8 megayear dt: 25860.5 year (2020-02-19 02:28:35)
# Step:   118 Model Time: 5.8 megayear dt: 25635.7 year (2020-02-19 02:28:58)
# Step:   119 Model Time: 5.8 megayear dt: 25485.2 year (2020-02-19 02:29:21)
# Step:   120 Model Time: 5.8 megayear dt: 24966.8 year (2020-02-19 02:29:44)
# Step:   121 Model Time: 5.9 megayear dt: 24482.9 year (2020-02-19 02:30:08)
# Step:   122 Model Time: 5.9 megayear dt: 23732.9 year (2020-02-19 02:30:32)
# Step:   123 Model Time: 5.9 megayear dt: 23049.5 year (2020-02-19 02:30:55)
# Step:   124 Model Time: 5.9 megayear dt: 22916.1 year (2020-02-19 02:31:19)
# Step:   125 Model Time: 5.9 megayear dt: 23043.9 year (2020-02-19 02:31:42)
# Step:   126 Model Time: 6.0 megayear dt: 23211.1 year (2020-02-19 02:32:08)
# Step:   127 Model Time: 6.0 megayear dt: 23537.6 year (2020-02-19 02:32:34)
# Step:   128 Model Time: 6.0 megayear dt: 4989.1 year (2020-02-19 02:33:51)
# Step:   129 Model Time: 6.0 megayear dt: 23617.8 year (2020-02-19 02:34:15)
# Step:   130 Model Time: 6.0 megayear dt: 23507.6 year (2020-02-19 02:34:38)
# Step:   131 Model Time: 6.1 megayear dt: 23458.7 year (2020-02-19 02:35:00)
# Step:   132 Model Time: 6.1 megayear dt: 23518.4 year (2020-02-19 02:35:24)
# Step:   133 Model Time: 6.1 megayear dt: 23474.5 year (2020-02-19 02:35:47)
# Step:   134 Model Time: 6.1 megayear dt: 23419.3 year (2020-02-19 02:36:11)
# Step:   135 Model Time: 6.2 megayear dt: 23316.3 year (2020-02-19 02:36:34)
# Step:   136 Model Time: 6.2 megayear dt: 23250.0 year (2020-02-19 02:36:57)
# Step:   137 Model Time: 6.2 megayear dt: 23134.8 year (2020-02-19 02:37:20)
# Step:   138 Model Time: 6.2 megayear dt: 23114.3 year (2020-02-19 02:37:44)
# Step:   139 Model Time: 6.3 megayear dt: 23007.3 year (2020-02-19 02:38:07)
# Step:   140 Model Time: 6.3 megayear dt: 22906.4 year (2020-02-19 02:38:30)
# Step:   141 Model Time: 6.3 megayear dt: 22805.5 year (2020-02-19 02:38:54)
# Step:   142 Model Time: 6.3 megayear dt: 22793.6 year (2020-02-19 02:39:17)
# Step:   143 Model Time: 6.3 megayear dt: 22629.1 year (2020-02-19 02:39:40)
# Step:   144 Model Time: 6.4 megayear dt: 22518.2 year (2020-02-19 02:40:03)
# Step:   145 Model Time: 6.4 megayear dt: 22491.5 year (2020-02-19 02:40:26)
# Step:   146 Model Time: 6.4 megayear dt: 22473.5 year (2020-02-19 02:40:49)
# Step:   147 Model Time: 6.4 megayear dt: 22368.3 year (2020-02-19 02:41:13)
# Step:   148 Model Time: 6.5 megayear dt: 22303.3 year (2020-02-19 02:41:36)
# Step:   149 Model Time: 6.5 megayear dt: 22098.0 year (2020-02-19 02:42:00)
# Step:   150 Model Time: 6.5 megayear dt: 17793.4 year (2020-02-19 02:43:10)
# Step:   151 Model Time: 6.5 megayear dt: 22133.1 year (2020-02-19 02:43:34)
# Step:   152 Model Time: 6.5 megayear dt: 21938.2 year (2020-02-19 02:43:57)
# Step:   153 Model Time: 6.6 megayear dt: 22059.3 year (2020-02-19 02:44:20)
# Step:   154 Model Time: 6.6 megayear dt: 21872.5 year (2020-02-19 02:44:44)
# Step:   155 Model Time: 6.6 megayear dt: 21981.1 year (2020-02-19 02:45:07)
# Step:   156 Model Time: 6.6 megayear dt: 21962.9 year (2020-02-19 02:45:30)
# Step:   157 Model Time: 6.7 megayear dt: 21943.5 year (2020-02-19 02:45:53)
# Step:   158 Model Time: 6.7 megayear dt: 22031.2 year (2020-02-19 02:46:16)
# Step:   159 Model Time: 6.7 megayear dt: 21957.8 year (2020-02-19 02:46:39)
# Step:   160 Model Time: 6.7 megayear dt: 21861.6 year (2020-02-19 02:47:02)
# Step:   161 Model Time: 6.7 megayear dt: 21861.7 year (2020-02-19 02:47:25)
# Step:   162 Model Time: 6.8 megayear dt: 21795.1 year (2020-02-19 02:47:49)
# Step:   163 Model Time: 6.8 megayear dt: 21639.5 year (2020-02-19 02:48:12)
# Step:   164 Model Time: 6.8 megayear dt: 21560.4 year (2020-02-19 02:48:35)
# Step:   165 Model Time: 6.8 megayear dt: 21544.4 year (2020-02-19 02:48:58)
# Step:   166 Model Time: 6.8 megayear dt: 21615.3 year (2020-02-19 02:49:21)
# Step:   167 Model Time: 6.9 megayear dt: 21508.8 year (2020-02-19 02:49:45)
# Step:   168 Model Time: 6.9 megayear dt: 21765.0 year (2020-02-19 02:50:08)
# Step:   169 Model Time: 6.9 megayear dt: 21521.1 year (2020-02-19 02:50:31)
# Step:   170 Model Time: 6.9 megayear dt: 21807.9 year (2020-02-19 02:50:55)
# Step:   171 Model Time: 7.0 megayear dt: 21782.6 year (2020-02-19 02:51:18)
# Step:   172 Model Time: 7.0 megayear dt: 21643.3 year (2020-02-19 02:51:41)
# Step:   173 Model Time: 7.0 megayear dt: 20213.6 year (2020-02-19 02:52:52)
# Step:   174 Model Time: 7.0 megayear dt: 21844.3 year (2020-02-19 02:53:15)
# Step:   175 Model Time: 7.0 megayear dt: 21803.9 year (2020-02-19 02:53:39)
# Step:   176 Model Time: 7.1 megayear dt: 21758.3 year (2020-02-19 02:54:03)
# Step:   177 Model Time: 7.1 megayear dt: 22055.6 year (2020-02-19 02:54:27)
# Step:   178 Model Time: 7.1 megayear dt: 22198.9 year (2020-02-19 02:54:50)
# Step:   179 Model Time: 7.1 megayear dt: 22253.4 year (2020-02-19 02:55:13)
# Step:   180 Model Time: 7.2 megayear dt: 22446.5 year (2020-02-19 02:55:36)
# Step:   181 Model Time: 7.2 megayear dt: 22445.8 year (2020-02-19 02:55:59)
# Step:   182 Model Time: 7.2 megayear dt: 22622.5 year (2020-02-19 02:56:22)
# Step:   183 Model Time: 7.2 megayear dt: 22458.5 year (2020-02-19 02:56:45)
# Step:   184 Model Time: 7.2 megayear dt: 22831.7 year (2020-02-19 02:57:08)
# Step:   185 Model Time: 7.3 megayear dt: 23004.0 year (2020-02-19 02:57:32)
# Step:   186 Model Time: 7.3 megayear dt: 23228.4 year (2020-02-19 02:57:55)
# Step:   187 Model Time: 7.3 megayear dt: 23442.4 year (2020-02-19 02:58:18)
# Step:   188 Model Time: 7.3 megayear dt: 23407.9 year (2020-02-19 02:58:41)
# Step:   189 Model Time: 7.4 megayear dt: 23973.4 year (2020-02-19 02:59:04)
# Step:   190 Model Time: 7.4 megayear dt: 24101.4 year (2020-02-19 02:59:28)
# Step:   191 Model Time: 7.4 megayear dt: 23912.2 year (2020-02-19 02:59:51)
# Step:   192 Model Time: 7.4 megayear dt: 24241.8 year (2020-02-19 03:00:14)
# Step:   193 Model Time: 7.5 megayear dt: 24392.5 year (2020-02-19 03:00:38)
# Step:   194 Model Time: 7.5 megayear dt: 24285.8 year (2020-02-19 03:01:01)
# Step:   195 Model Time: 7.5 megayear dt: 17290.7 year (2020-02-19 03:02:12)
# Step:   196 Model Time: 7.5 megayear dt: 25157.2 year (2020-02-19 03:02:35)
# Step:   197 Model Time: 7.6 megayear dt: 25062.8 year (2020-02-19 03:02:58)
# Step:   198 Model Time: 7.6 megayear dt: 25147.6 year (2020-02-19 03:03:22)
# Step:   199 Model Time: 7.6 megayear dt: 25229.5 year (2020-02-19 03:03:45)
# Step:   200 Model Time: 7.6 megayear dt: 25494.9 year (2020-02-19 03:04:09)
# Step:   201 Model Time: 7.7 megayear dt: 25810.5 year (2020-02-19 03:04:32)
# Step:   202 Model Time: 7.7 megayear dt: 26111.4 year (2020-02-19 03:04:55)
# Step:   203 Model Time: 7.7 megayear dt: 26451.5 year (2020-02-19 03:05:19)
# Step:   204 Model Time: 7.7 megayear dt: 26903.4 year (2020-02-19 03:05:43)
# Step:   205 Model Time: 7.8 megayear dt: 26919.7 year (2020-02-19 03:06:06)
# Step:   206 Model Time: 7.8 megayear dt: 27768.8 year (2020-02-19 03:06:30)
# Step:   207 Model Time: 7.8 megayear dt: 28572.4 year (2020-02-19 03:06:54)
# Step:   208 Model Time: 7.8 megayear dt: 28592.6 year (2020-02-19 03:07:17)
# Step:   209 Model Time: 7.9 megayear dt: 28127.1 year (2020-02-19 03:07:41)
# Step:   210 Model Time: 7.9 megayear dt: 27969.6 year (2020-02-19 03:08:04)
# Step:   211 Model Time: 7.9 megayear dt: 28202.2 year (2020-02-19 03:08:27)
# Step:   212 Model Time: 8.0 megayear dt: 28436.7 year (2020-02-19 03:08:51)
# Step:   213 Model Time: 8.0 megayear dt: 28740.4 year (2020-02-19 03:09:14)
# Step:   214 Model Time: 8.0 megayear dt: 15301.5 year (2020-02-19 03:10:25)
# Step:   215 Model Time: 8.0 megayear dt: 29135.2 year (2020-02-19 03:10:48)
# Step:   216 Model Time: 8.1 megayear dt: 29464.1 year (2020-02-19 03:11:11)
# Step:   217 Model Time: 8.1 megayear dt: 30171.9 year (2020-02-19 03:11:34)
# Step:   218 Model Time: 8.1 megayear dt: 30696.4 year (2020-02-19 03:11:58)
# Step:   219 Model Time: 8.2 megayear dt: 31083.4 year (2020-02-19 03:12:21)
# Step:   220 Model Time: 8.2 megayear dt: 31528.2 year (2020-02-19 03:12:44)
# Step:   221 Model Time: 8.2 megayear dt: 31889.7 year (2020-02-19 03:13:07)
# Step:   222 Model Time: 8.2 megayear dt: 32373.8 year (2020-02-19 03:13:30)
# Step:   223 Model Time: 8.3 megayear dt: 32285.2 year (2020-02-19 03:13:53)
# Step:   224 Model Time: 8.3 megayear dt: 32187.6 year (2020-02-19 03:14:17)
# Step:   225 Model Time: 8.3 megayear dt: 31991.7 year (2020-02-19 03:14:40)
# Step:   226 Model Time: 8.4 megayear dt: 31792.0 year (2020-02-19 03:15:03)
# Step:   227 Model Time: 8.4 megayear dt: 32278.8 year (2020-02-19 03:15:26)
# Step:   228 Model Time: 8.4 megayear dt: 32736.0 year (2020-02-19 03:15:49)
# Step:   229 Model Time: 8.5 megayear dt: 33235.8 year (2020-02-19 03:16:13)
# Step:   230 Model Time: 8.5 megayear dt: 27150.2 year (2020-02-19 03:17:27)
# Step:   231 Model Time: 8.5 megayear dt: 32758.6 year (2020-02-19 03:17:50)
# Step:   232 Model Time: 8.6 megayear dt: 32472.7 year (2020-02-19 03:18:13)
# Step:   233 Model Time: 8.6 megayear dt: 33166.4 year (2020-02-19 03:18:36)
# Step:   234 Model Time: 8.6 megayear dt: 33452.1 year (2020-02-19 03:18:59)
# Step:   235 Model Time: 8.7 megayear dt: 33353.9 year (2020-02-19 03:19:22)
# Step:   236 Model Time: 8.7 megayear dt: 33085.6 year (2020-02-19 03:19:45)
# Step:   237 Model Time: 8.7 megayear dt: 33345.2 year (2020-02-19 03:20:09)
# Step:   238 Model Time: 8.8 megayear dt: 33404.7 year (2020-02-19 03:20:32)
# Step:   239 Model Time: 8.8 megayear dt: 33333.3 year (2020-02-19 03:20:56)
# Step:   240 Model Time: 8.8 megayear dt: 33325.8 year (2020-02-19 03:21:20)
# Step:   241 Model Time: 8.9 megayear dt: 33233.6 year (2020-02-19 03:21:43)
# Step:   242 Model Time: 8.9 megayear dt: 33183.6 year (2020-02-19 03:22:06)
# Step:   243 Model Time: 8.9 megayear dt: 33025.1 year (2020-02-19 03:22:29)
# Step:   244 Model Time: 9.0 megayear dt: 33033.0 year (2020-02-19 03:22:53)
# Step:   245 Model Time: 9.0 megayear dt: 33524.4 year (2020-02-19 03:23:17)
# Step:   246 Model Time: 9.0 megayear dt: 2302.1 year (2020-02-19 03:24:28)
# Step:   247 Model Time: 9.0 megayear dt: 34036.2 year (2020-02-19 03:24:52)
# Step:   248 Model Time: 9.1 megayear dt: 34112.0 year (2020-02-19 03:25:15)
# Step:   249 Model Time: 9.1 megayear dt: 33938.6 year (2020-02-19 03:25:40)
# Step:   250 Model Time: 9.1 megayear dt: 34070.7 year (2020-02-19 03:26:06)
# Step:   251 Model Time: 9.2 megayear dt: 33761.9 year (2020-02-19 03:26:33)
# Step:   252 Model Time: 9.2 megayear dt: 33663.0 year (2020-02-19 03:26:57)
# Step:   253 Model Time: 9.2 megayear dt: 34508.6 year (2020-02-19 03:27:20)
# Step:   254 Model Time: 9.3 megayear dt: 34621.7 year (2020-02-19 03:27:44)
# Step:   255 Model Time: 9.3 megayear dt: 34619.3 year (2020-02-19 03:28:07)
# Step:   256 Model Time: 9.3 megayear dt: 34468.7 year (2020-02-19 03:28:31)
# Step:   257 Model Time: 9.4 megayear dt: 34635.1 year (2020-02-19 03:28:54)
# Step:   258 Model Time: 9.4 megayear dt: 35037.0 year (2020-02-19 03:29:18)
# Step:   259 Model Time: 9.4 megayear dt: 34883.9 year (2020-02-19 03:29:41)
# Step:   260 Model Time: 9.5 megayear dt: 35073.3 year (2020-02-19 03:30:04)
# Step:   261 Model Time: 9.5 megayear dt: 18570.0 year (2020-02-19 03:31:15)
# Step:   262 Model Time: 9.5 megayear dt: 34758.9 year (2020-02-19 03:31:39)
# Step:   263 Model Time: 9.6 megayear dt: 34778.8 year (2020-02-19 03:32:02)
# Step:   264 Model Time: 9.6 megayear dt: 35202.5 year (2020-02-19 03:32:25)
# Step:   265 Model Time: 9.6 megayear dt: 35269.1 year (2020-02-19 03:32:48)
# Step:   266 Model Time: 9.7 megayear dt: 35503.1 year (2020-02-19 03:33:11)
# Step:   267 Model Time: 9.7 megayear dt: 35902.3 year (2020-02-19 03:33:34)
# Step:   268 Model Time: 9.7 megayear dt: 36821.3 year (2020-02-19 03:33:58)
# Step:   269 Model Time: 9.8 megayear dt: 37337.8 year (2020-02-19 03:34:21)
# Step:   270 Model Time: 9.8 megayear dt: 37590.5 year (2020-02-19 03:34:45)
# Step:   271 Model Time: 9.9 megayear dt: 38327.0 year (2020-02-19 03:35:07)
# Step:   272 Model Time: 9.9 megayear dt: 38658.6 year (2020-02-19 03:35:31)
# Step:   273 Model Time: 9.9 megayear dt: 39098.2 year (2020-02-19 03:35:54)
# Step:   274 Model Time: 10.0 megayear dt: 39402.4 year (2020-02-19 03:36:17)
# Step:   275 Model Time: 10.0 megayear dt: 21349.5 year (2020-02-19 03:37:29)
# Step:   276 Model Time: 10.0 megayear dt: 39310.2 year (2020-02-19 03:37:52)
# Step:   277 Model Time: 10.1 megayear dt: 40287.9 year (2020-02-19 03:38:15)
# Step:   278 Model Time: 10.1 megayear dt: 40086.8 year (2020-02-19 03:38:39)
# Step:   279 Model Time: 10.2 megayear dt: 40310.9 year (2020-02-19 03:39:02)
# Step:   280 Model Time: 10.2 megayear dt: 40970.5 year (2020-02-19 03:39:25)
# Step:   281 Model Time: 10.2 megayear dt: 41360.4 year (2020-02-19 03:39:48)
# Step:   282 Model Time: 10.3 megayear dt: 41517.8 year (2020-02-19 03:40:12)
# Step:   283 Model Time: 10.3 megayear dt: 41596.8 year (2020-02-19 03:40:35)
# Step:   284 Model Time: 10.4 megayear dt: 42700.1 year (2020-02-19 03:40:59)
# Step:   285 Model Time: 10.4 megayear dt: 43558.8 year (2020-02-19 03:41:23)
# Step:   286 Model Time: 10.5 megayear dt: 43952.6 year (2020-02-19 03:41:46)
# Step:   287 Model Time: 10.5 megayear dt: 44347.1 year (2020-02-19 03:42:57)
# Step:   288 Model Time: 10.5 megayear dt: 46025.4 year (2020-02-19 03:43:20)
# Step:   289 Model Time: 10.6 megayear dt: 46241.4 year (2020-02-19 03:43:43)
# Step:   290 Model Time: 10.6 megayear dt: 47264.0 year (2020-02-19 03:44:06)
# Step:   291 Model Time: 10.7 megayear dt: 47838.9 year (2020-02-19 03:44:29)
# Step:   292 Model Time: 10.7 megayear dt: 49106.3 year (2020-02-19 03:44:53)
# Step:   293 Model Time: 10.8 megayear dt: 49824.2 year (2020-02-19 03:45:16)
# Step:   294 Model Time: 10.8 megayear dt: 50525.6 year (2020-02-19 03:45:39)
# Step:   295 Model Time: 10.9 megayear dt: 51327.8 year (2020-02-19 03:46:02)
# Step:   296 Model Time: 10.9 megayear dt: 52089.5 year (2020-02-19 03:46:26)
# Step:   297 Model Time: 11.0 megayear dt: 51896.4 year (2020-02-19 03:46:50)
# Step:   298 Model Time: 11.0 megayear dt: 7860.5 year (2020-02-19 03:48:01)
# Step:   299 Model Time: 11.1 megayear dt: 53217.7 year (2020-02-19 03:48:25)
# Step:   300 Model Time: 11.1 megayear dt: 53245.9 year (2020-02-19 03:48:48)
# Step:   301 Model Time: 11.2 megayear dt: 54880.0 year (2020-02-19 03:49:12)
# Step:   302 Model Time: 11.2 megayear dt: 55500.4 year (2020-02-19 03:49:35)
# Step:   303 Model Time: 11.3 megayear dt: 56155.5 year (2020-02-19 03:49:59)
# Step:   304 Model Time: 11.3 megayear dt: 56607.3 year (2020-02-19 03:50:22)
# Step:   305 Model Time: 11.4 megayear dt: 56940.9 year (2020-02-19 03:50:45)
# Step:   306 Model Time: 11.4 megayear dt: 57920.2 year (2020-02-19 03:51:09)
# Step:   307 Model Time: 11.5 megayear dt: 55532.3 year (2020-02-19 03:52:20)
# Step:   308 Model Time: 11.6 megayear dt: 58557.1 year (2020-02-19 03:52:44)
# Step:   309 Model Time: 11.6 megayear dt: 59276.1 year (2020-02-19 03:53:07)
# Step:   310 Model Time: 11.7 megayear dt: 59565.4 year (2020-02-19 03:53:31)
# Step:   311 Model Time: 11.7 megayear dt: 60631.4 year (2020-02-19 03:53:54)
# Step:   312 Model Time: 11.8 megayear dt: 61108.4 year (2020-02-19 03:54:20)
# Step:   313 Model Time: 11.9 megayear dt: 61535.9 year (2020-02-19 03:54:45)
# Step:   314 Model Time: 11.9 megayear dt: 60840.0 year (2020-02-19 03:55:08)
# Step:   315 Model Time: 12.0 megayear dt: 61259.0 year (2020-02-19 03:55:31)
# Step:   316 Model Time: 12.0 megayear dt: 17226.5 year (2020-02-19 03:56:42)
# Step:   317 Model Time: 12.1 megayear dt: 60418.7 year (2020-02-19 03:57:06)
# Step:   318 Model Time: 12.1 megayear dt: 61611.7 year (2020-02-19 03:57:30)
# Step:   319 Model Time: 12.2 megayear dt: 61998.9 year (2020-02-19 03:57:54)
# Step:   320 Model Time: 12.2 megayear dt: 63192.9 year (2020-02-19 03:58:17)
# Step:   321 Model Time: 12.3 megayear dt: 62706.2 year (2020-02-19 03:58:41)
# Step:   322 Model Time: 12.4 megayear dt: 62607.6 year (2020-02-19 03:59:04)
# Step:   323 Model Time: 12.4 megayear dt: 62461.4 year (2020-02-19 03:59:28)
# Step:   324 Model Time: 12.5 megayear dt: 62331.7 year (2020-02-19 03:59:51)
# Step:   325 Model Time: 12.5 megayear dt: 2670.9 year (2020-02-19 04:01:03)
# Step:   326 Model Time: 12.6 megayear dt: 62170.0 year (2020-02-19 04:01:27)
# Step:   327 Model Time: 12.6 megayear dt: 61778.7 year (2020-02-19 04:01:51)
# Step:   328 Model Time: 12.7 megayear dt: 62400.3 year (2020-02-19 04:02:14)
# Step:   329 Model Time: 12.7 megayear dt: 61896.0 year (2020-02-19 04:02:38)
# Step:   330 Model Time: 12.8 megayear dt: 62322.3 year (2020-02-19 04:03:02)
# Step:   331 Model Time: 12.9 megayear dt: 62037.3 year (2020-02-19 04:03:26)
# Step:   332 Model Time: 12.9 megayear dt: 62533.6 year (2020-02-19 04:03:49)
# Step:   333 Model Time: 13.0 megayear dt: 61940.3 year (2020-02-19 04:04:13)
# Step:   334 Model Time: 13.0 megayear dt: 2921.5 year (2020-02-19 04:05:25)
# Step:   335 Model Time: 13.1 megayear dt: 61183.4 year (2020-02-19 04:05:49)
# Step:   336 Model Time: 13.1 megayear dt: 61201.7 year (2020-02-19 04:06:13)
# Step:   337 Model Time: 13.2 megayear dt: 61769.9 year (2020-02-19 04:06:36)
# Step:   338 Model Time: 13.2 megayear dt: 61144.4 year (2020-02-19 04:06:59)
# Step:   339 Model Time: 13.3 megayear dt: 61683.0 year (2020-02-19 04:07:23)
# Step:   340 Model Time: 13.4 megayear dt: 61231.9 year (2020-02-19 04:07:47)
# Step:   341 Model Time: 13.4 megayear dt: 59695.8 year (2020-02-19 04:08:10)
# Step:   342 Model Time: 13.5 megayear dt: 60553.9 year (2020-02-19 04:08:34)
# Step:   343 Model Time: 13.5 megayear dt: 11535.9 year (2020-02-19 04:09:45)
# Step:   344 Model Time: 13.6 megayear dt: 59909.7 year (2020-02-19 04:10:09)
# Step:   345 Model Time: 13.6 megayear dt: 59141.3 year (2020-02-19 04:10:32)
# Step:   346 Model Time: 13.7 megayear dt: 59054.9 year (2020-02-19 04:10:56)
# Step:   347 Model Time: 13.7 megayear dt: 57759.7 year (2020-02-19 04:11:19)
# Step:   348 Model Time: 13.8 megayear dt: 58043.3 year (2020-02-19 04:11:42)
# Step:   349 Model Time: 13.9 megayear dt: 57449.0 year (2020-02-19 04:12:05)
# Step:   350 Model Time: 13.9 megayear dt: 56844.3 year (2020-02-19 04:12:29)
# Step:   351 Model Time: 14.0 megayear dt: 55877.8 year (2020-02-19 04:12:52)
# Step:   352 Model Time: 14.0 megayear dt: 35920.1 year (2020-02-19 04:14:04)
# Step:   353 Model Time: 14.1 megayear dt: 55529.3 year (2020-02-19 04:14:27)
# Step:   354 Model Time: 14.1 megayear dt: 53297.3 year (2020-02-19 04:14:51)
# Step:   355 Model Time: 14.2 megayear dt: 53870.6 year (2020-02-19 04:15:14)
# Step:   356 Model Time: 14.2 megayear dt: 52798.7 year (2020-02-19 04:15:38)
# Step:   357 Model Time: 14.3 megayear dt: 52695.3 year (2020-02-19 04:16:02)
# Step:   358 Model Time: 14.3 megayear dt: 53181.2 year (2020-02-19 04:16:25)
# Step:   359 Model Time: 14.4 megayear dt: 52417.6 year (2020-02-19 04:16:48)
# Step:   360 Model Time: 14.4 megayear dt: 52246.1 year (2020-02-19 04:17:11)
# Step:   361 Model Time: 14.5 megayear dt: 50852.0 year (2020-02-19 04:17:35)
# Step:   362 Model Time: 14.5 megayear dt: 23111.8 year (2020-02-19 04:18:46)
# Step:   363 Model Time: 14.5 megayear dt: 49728.6 year (2020-02-19 04:19:10)
# Step:   364 Model Time: 14.6 megayear dt: 49247.7 year (2020-02-19 04:19:33)
# Step:   365 Model Time: 14.6 megayear dt: 48509.9 year (2020-02-19 04:19:56)
# Step:   366 Model Time: 14.7 megayear dt: 47886.8 year (2020-02-19 04:20:20)
# Step:   367 Model Time: 14.7 megayear dt: 47960.1 year (2020-02-19 04:20:43)
# Step:   368 Model Time: 14.8 megayear dt: 47436.3 year (2020-02-19 04:21:07)
# Step:   369 Model Time: 14.8 megayear dt: 46650.8 year (2020-02-19 04:21:30)
# Step:   370 Model Time: 14.9 megayear dt: 46729.4 year (2020-02-19 04:21:53)
# Step:   371 Model Time: 14.9 megayear dt: 45666.4 year (2020-02-19 04:22:16)
# Step:   372 Model Time: 15.0 megayear dt: 44998.0 year (2020-02-19 04:22:40)
# Step:   373 Model Time: 15.0 megayear dt: 25185.9 year (2020-02-19 04:23:51)
# Step:   374 Model Time: 15.0 megayear dt: 44722.6 year (2020-02-19 04:24:15)
# Step:   375 Model Time: 15.1 megayear dt: 44700.3 year (2020-02-19 04:24:38)
# Step:   376 Model Time: 15.1 megayear dt: 43551.6 year (2020-02-19 04:25:02)
# Step:   377 Model Time: 15.2 megayear dt: 43406.5 year (2020-02-19 04:25:25)
# Step:   378 Model Time: 15.2 megayear dt: 43040.2 year (2020-02-19 04:25:48)
# Step:   379 Model Time: 15.3 megayear dt: 42412.1 year (2020-02-19 04:26:11)
# Step:   380 Model Time: 15.3 megayear dt: 42257.5 year (2020-02-19 04:26:35)
# Step:   381 Model Time: 15.3 megayear dt: 41574.4 year (2020-02-19 04:26:58)
# Step:   382 Model Time: 15.4 megayear dt: 41459.2 year (2020-02-19 04:27:21)
# Step:   383 Model Time: 15.4 megayear dt: 41204.7 year (2020-02-19 04:27:45)
# Step:   384 Model Time: 15.5 megayear dt: 40618.7 year (2020-02-19 04:28:09)
# Step:   385 Model Time: 15.5 megayear dt: 31052.3 year (2020-02-19 04:29:21)
# Step:   386 Model Time: 15.5 megayear dt: 39521.5 year (2020-02-19 04:29:45)
# Step:   387 Model Time: 15.6 megayear dt: 39162.1 year (2020-02-19 04:30:08)
# Step:   388 Model Time: 15.6 megayear dt: 38993.1 year (2020-02-19 04:30:31)
# Step:   389 Model Time: 15.7 megayear dt: 37929.4 year (2020-02-19 04:30:55)
# Step:   390 Model Time: 15.7 megayear dt: 38264.0 year (2020-02-19 04:31:18)
# Step:   391 Model Time: 15.7 megayear dt: 37582.7 year (2020-02-19 04:31:41)
# Step:   392 Model Time: 15.8 megayear dt: 37035.4 year (2020-02-19 04:32:04)
# Step:   393 Model Time: 15.8 megayear dt: 36797.6 year (2020-02-19 04:32:27)
# Step:   394 Model Time: 15.8 megayear dt: 36605.8 year (2020-02-19 04:32:51)
# Step:   395 Model Time: 15.9 megayear dt: 36486.9 year (2020-02-19 04:33:14)
# Step:   396 Model Time: 15.9 megayear dt: 36750.4 year (2020-02-19 04:33:37)
# Step:   397 Model Time: 16.0 megayear dt: 36908.9 year (2020-02-19 04:34:01)
# Step:   398 Model Time: 16.0 megayear dt: 36236.0 year (2020-02-19 04:34:24)
# Step:   399 Model Time: 16.0 megayear dt: 11726.3 year (2020-02-19 04:35:35)
# Step:   400 Model Time: 16.0 megayear dt: 36409.3 year (2020-02-19 04:35:58)
# Step:   401 Model Time: 16.1 megayear dt: 36039.1 year (2020-02-19 04:36:22)
# Step:   402 Model Time: 16.1 megayear dt: 35650.8 year (2020-02-19 04:36:45)
# Step:   403 Model Time: 16.1 megayear dt: 35782.3 year (2020-02-19 04:37:09)
# Step:   404 Model Time: 16.2 megayear dt: 35575.8 year (2020-02-19 04:37:32)
# Step:   405 Model Time: 16.2 megayear dt: 35049.6 year (2020-02-19 04:37:56)
# Step:   406 Model Time: 16.2 megayear dt: 35467.3 year (2020-02-19 04:38:19)
# Step:   407 Model Time: 16.3 megayear dt: 35402.0 year (2020-02-19 04:38:43)
# Step:   408 Model Time: 16.3 megayear dt: 35217.8 year (2020-02-19 04:39:06)
# Step:   409 Model Time: 16.4 megayear dt: 34628.6 year (2020-02-19 04:39:29)
# Step:   410 Model Time: 16.4 megayear dt: 34219.7 year (2020-02-19 04:39:52)
# Step:   411 Model Time: 16.4 megayear dt: 34136.3 year (2020-02-19 04:40:16)
# Step:   412 Model Time: 16.5 megayear dt: 33901.1 year (2020-02-19 04:40:39)
# Step:   413 Model Time: 16.5 megayear dt: 33700.7 year (2020-02-19 04:41:03)
# Step:   414 Model Time: 16.5 megayear dt: 8819.5 year (2020-02-19 04:42:15)
# Step:   415 Model Time: 16.5 megayear dt: 33594.0 year (2020-02-19 04:42:38)
# Step:   416 Model Time: 16.6 megayear dt: 33924.8 year (2020-02-19 04:43:02)
# Step:   417 Model Time: 16.6 megayear dt: 34038.6 year (2020-02-19 04:43:25)
# Step:   418 Model Time: 16.6 megayear dt: 33663.7 year (2020-02-19 04:43:49)
# Step:   419 Model Time: 16.7 megayear dt: 33902.9 year (2020-02-19 04:44:13)
# Step:   420 Model Time: 16.7 megayear dt: 33436.5 year (2020-02-19 04:44:36)
# Step:   421 Model Time: 16.7 megayear dt: 34316.7 year (2020-02-19 04:45:00)
# Step:   422 Model Time: 16.8 megayear dt: 34188.5 year (2020-02-19 04:45:23)
# Step:   423 Model Time: 16.8 megayear dt: 34817.7 year (2020-02-19 04:45:47)
# Step:   424 Model Time: 16.8 megayear dt: 34254.4 year (2020-02-19 04:46:11)
# Step:   425 Model Time: 16.9 megayear dt: 34499.9 year (2020-02-19 04:46:34)
# Step:   426 Model Time: 16.9 megayear dt: 34338.4 year (2020-02-19 04:46:58)
# Step:   427 Model Time: 16.9 megayear dt: 34578.0 year (2020-02-19 04:47:21)
# Step:   428 Model Time: 17.0 megayear dt: 34521.1 year (2020-02-19 04:47:45)
# Step:   429 Model Time: 17.0 megayear dt: 21924.9 year (2020-02-19 04:48:57)
# Step:   430 Model Time: 17.0 megayear dt: 34798.3 year (2020-02-19 04:49:22)
# Step:   431 Model Time: 17.1 megayear dt: 34790.3 year (2020-02-19 04:49:45)
# Step:   432 Model Time: 17.1 megayear dt: 34939.9 year (2020-02-19 04:50:09)
# Step:   433 Model Time: 17.1 megayear dt: 35036.5 year (2020-02-19 04:50:33)
# Step:   434 Model Time: 17.2 megayear dt: 35521.3 year (2020-02-19 04:50:56)
# Step:   435 Model Time: 17.2 megayear dt: 35148.8 year (2020-02-19 04:51:20)
# Step:   436 Model Time: 17.2 megayear dt: 35145.6 year (2020-02-19 04:51:43)
# Step:   437 Model Time: 17.3 megayear dt: 35434.9 year (2020-02-19 04:52:07)
# Step:   438 Model Time: 17.3 megayear dt: 35343.6 year (2020-02-19 04:52:31)
# Step:   439 Model Time: 17.4 megayear dt: 35700.7 year (2020-02-19 04:52:55)
# Step:   440 Model Time: 17.4 megayear dt: 35833.5 year (2020-02-19 04:53:18)
# Step:   441 Model Time: 17.4 megayear dt: 35575.2 year (2020-02-19 04:53:42)
# Step:   442 Model Time: 17.5 megayear dt: 35845.9 year (2020-02-19 04:54:05)
# Step:   443 Model Time: 17.5 megayear dt: 36173.7 year (2020-02-19 04:54:29)
# Step:   444 Model Time: 17.5 megayear dt: 4711.7 year (2020-02-19 04:55:42)
# Step:   445 Model Time: 17.5 megayear dt: 36681.7 year (2020-02-19 04:56:05)
# Step:   446 Model Time: 17.6 megayear dt: 36411.9 year (2020-02-19 04:56:28)
# Step:   447 Model Time: 17.6 megayear dt: 36911.8 year (2020-02-19 04:56:51)
# Step:   448 Model Time: 17.6 megayear dt: 37090.0 year (2020-02-19 04:57:15)
# Step:   449 Model Time: 17.7 megayear dt: 37503.7 year (2020-02-19 04:57:39)
# Step:   450 Model Time: 17.7 megayear dt: 38323.2 year (2020-02-19 04:58:03)
# Step:   451 Model Time: 17.8 megayear dt: 38668.9 year (2020-02-19 04:58:26)
# Step:   452 Model Time: 17.8 megayear dt: 38944.7 year (2020-02-19 04:58:50)
# Step:   453 Model Time: 17.8 megayear dt: 39133.3 year (2020-02-19 04:59:14)
# Step:   454 Model Time: 17.9 megayear dt: 39348.7 year (2020-02-19 04:59:38)
# Step:   455 Model Time: 17.9 megayear dt: 39581.6 year (2020-02-19 05:00:01)
# Step:   456 Model Time: 18.0 megayear dt: 40265.9 year (2020-02-19 05:00:24)
# Step:   457 Model Time: 18.0 megayear dt: 40465.6 year (2020-02-19 05:00:48)
# Step:   458 Model Time: 18.0 megayear dt: 668.9 year (2020-02-19 05:02:00)
# Step:   459 Model Time: 18.0 megayear dt: 41016.9 year (2020-02-19 05:02:23)
# Step:   460 Model Time: 18.1 megayear dt: 41073.2 year (2020-02-19 05:02:47)
# Step:   461 Model Time: 18.1 megayear dt: 41106.2 year (2020-02-19 05:03:11)
# Step:   462 Model Time: 18.2 megayear dt: 41488.0 year (2020-02-19 05:03:34)
# Step:   463 Model Time: 18.2 megayear dt: 41078.3 year (2020-02-19 05:03:58)
# Step:   464 Model Time: 18.2 megayear dt: 41896.2 year (2020-02-19 05:04:21)
# Step:   465 Model Time: 18.3 megayear dt: 41456.5 year (2020-02-19 05:04:45)
# Step:   466 Model Time: 18.3 megayear dt: 42232.4 year (2020-02-19 05:05:08)
# Step:   467 Model Time: 18.4 megayear dt: 41292.1 year (2020-02-19 05:05:32)
# Step:   468 Model Time: 18.4 megayear dt: 41651.0 year (2020-02-19 05:05:55)
# Step:   469 Model Time: 18.5 megayear dt: 42331.6 year (2020-02-19 05:06:18)
# Step:   470 Model Time: 18.5 megayear dt: 42650.7 year (2020-02-19 05:06:41)
# Step:   471 Model Time: 18.5 megayear dt: 726.9 year (2020-02-19 05:07:52)
# Step:   472 Model Time: 18.5 megayear dt: 44175.5 year (2020-02-19 05:08:15)
# Step:   473 Model Time: 18.6 megayear dt: 44645.1 year (2020-02-19 05:08:39)
# Step:   474 Model Time: 18.6 megayear dt: 44943.8 year (2020-02-19 05:09:02)
# Step:   475 Model Time: 18.7 megayear dt: 45712.4 year (2020-02-19 05:09:26)
# Step:   476 Model Time: 18.7 megayear dt: 45609.8 year (2020-02-19 05:09:49)
# Step:   477 Model Time: 18.8 megayear dt: 47328.6 year (2020-02-19 05:10:13)
# Step:   478 Model Time: 18.8 megayear dt: 47492.1 year (2020-02-19 05:10:36)
# Step:   479 Model Time: 18.9 megayear dt: 47417.3 year (2020-02-19 05:10:59)
# Step:   480 Model Time: 18.9 megayear dt: 48076.9 year (2020-02-19 05:11:22)
# Step:   481 Model Time: 19.0 megayear dt: 48517.9 year (2020-02-19 05:11:46)
# Step:   482 Model Time: 19.0 megayear dt: 36080.5 year (2020-02-19 05:12:57)
# Step:   483 Model Time: 19.1 megayear dt: 50297.8 year (2020-02-19 05:13:21)
# Step:   484 Model Time: 19.1 megayear dt: 52397.6 year (2020-02-19 05:13:44)
# Step:   485 Model Time: 19.2 megayear dt: 53425.7 year (2020-02-19 05:14:07)
# Step:   486 Model Time: 19.2 megayear dt: 53900.6 year (2020-02-19 05:14:30)
# Step:   487 Model Time: 19.3 megayear dt: 54185.7 year (2020-02-19 05:14:54)
# Step:   488 Model Time: 19.3 megayear dt: 54977.2 year (2020-02-19 05:15:18)
# Step:   489 Model Time: 19.4 megayear dt: 55097.8 year (2020-02-19 05:15:41)
# Step:   490 Model Time: 19.4 megayear dt: 55732.6 year (2020-02-19 05:16:05)
# Step:   491 Model Time: 19.5 megayear dt: 57457.3 year (2020-02-19 05:16:28)
# Step:   492 Model Time: 19.5 megayear dt: 12527.7 year (2020-02-19 05:17:39)
# Step:   493 Model Time: 19.6 megayear dt: 60862.3 year (2020-02-19 05:18:03)
# Step:   494 Model Time: 19.6 megayear dt: 60797.5 year (2020-02-19 05:18:26)
# Step:   495 Model Time: 19.7 megayear dt: 64441.1 year (2020-02-19 05:18:50)
# Step:   496 Model Time: 19.8 megayear dt: 65178.9 year (2020-02-19 05:19:14)
# Step:   497 Model Time: 19.8 megayear dt: 66095.2 year (2020-02-19 05:19:37)
# Step:   498 Model Time: 19.9 megayear dt: 65493.7 year (2020-02-19 05:20:01)
# Step:   499 Model Time: 19.9 megayear dt: 63136.7 year (2020-02-19 05:20:24)
# Step:   500 Model Time: 20.0 megayear dt: 53994.6 year (2020-02-19 05:21:36)
# Step:   501 Model Time: 20.1 megayear dt: 68488.8 year (2020-02-19 05:22:00)
# Step:   502 Model Time: 20.1 megayear dt: 70067.5 year (2020-02-19 05:22:23)
# Step:   507 Model Time: 20.5 megayear dt: 58205.9 year (2020-02-19 05:25:07)
# Step:   508 Model Time: 20.6 megayear dt: 79657.0 year (2020-02-19 05:25:31)
# Step:   509 Model Time: 20.7 megayear dt: 84737.4 year (2020-02-19 05:25:54)
# Step:   510 Model Time: 20.7 megayear dt: 85464.5 year (2020-02-19 05:26:17)
# Step:   511 Model Time: 20.8 megayear dt: 90911.6 year (2020-02-19 05:26:40)
# Step:   512 Model Time: 20.9 megayear dt: 95281.0 year (2020-02-19 05:27:03)
# Step:   513 Model Time: 21.0 megayear dt: 63948.6 year (2020-02-19 05:28:16)
# Step:   514 Model Time: 21.1 megayear dt: 105291.7 year (2020-02-19 05:28:39)
# Step:   515 Model Time: 21.2 megayear dt: 106765.0 year (2020-02-19 05:29:02)
# Step:   516 Model Time: 21.3 megayear dt: 105149.9 year (2020-02-19 05:29:26)
# Step:   517 Model Time: 21.4 megayear dt: 115409.2 year (2020-02-19 05:29:49)
# Step:   518 Model Time: 21.5 megayear dt: 67384.2 year (2020-02-19 05:30:59)
# Step:   519 Model Time: 21.6 megayear dt: 117604.2 year (2020-02-19 05:31:23)
# Step:   520 Model Time: 21.7 megayear dt: 126850.3 year (2020-02-19 05:31:46)
# Step:   521 Model Time: 21.9 megayear dt: 125065.7 year (2020-02-19 05:32:09)
# Step:   522 Model Time: 22.0 megayear dt: 130479.8 year (2020-02-19 05:33:19)
# Step:   523 Model Time: 22.1 megayear dt: 127343.4 year (2020-02-19 05:33:42)
# Step:   524 Model Time: 22.3 megayear dt: 138046.9 year (2020-02-19 05:34:06)
# Step:   525 Model Time: 22.4 megayear dt: 138631.5 year (2020-02-19 05:34:29)
# Step:   526 Model Time: 22.5 megayear dt: 95978.2 year (2020-02-19 05:35:41)
# Step:   527 Model Time: 22.6 megayear dt: 139950.0 year (2020-02-19 05:36:04)
# Step:   528 Model Time: 22.8 megayear dt: 141826.3 year (2020-02-19 05:36:28)
# Step:   529 Model Time: 22.9 megayear dt: 147154.4 year (2020-02-19 05:36:51)
# Step:   530 Model Time: 23.0 megayear dt: 71069.4 year (2020-02-19 05:38:06)
# Step:   531 Model Time: 23.1 megayear dt: 149180.4 year (2020-02-19 05:38:30)
# Step:   532 Model Time: 23.3 megayear dt: 143011.0 year (2020-02-19 05:38:53)
# Step:   533 Model Time: 23.4 megayear dt: 133881.2 year (2020-02-19 05:39:17)
# Step:   534 Model Time: 23.5 megayear dt: 73927.5 year (2020-02-19 05:40:28)
# Step:   535 Model Time: 23.6 megayear dt: 136975.4 year (2020-02-19 05:40:51)
# Step:   536 Model Time: 23.8 megayear dt: 140020.5 year (2020-02-19 05:41:14)
# Step:   537 Model Time: 23.9 megayear dt: 145660.3 year (2020-02-19 05:41:37)
# Step:   538 Model Time: 24.0 megayear dt: 77343.7 year (2020-02-19 05:42:48)
# Step:   539 Model Time: 24.2 megayear dt: 154369.0 year (2020-02-19 05:43:11)
# Step:   540 Model Time: 24.3 megayear dt: 162866.0 year (2020-02-19 05:43:34)
# Step:   541 Model Time: 24.5 megayear dt: 164695.0 year (2020-02-19 05:43:58)
# Step:   542 Model Time: 24.5 megayear dt: 18070.0 year (2020-02-19 05:45:08)
# Step:   543 Model Time: 24.7 megayear dt: 176774.3 year (2020-02-19 05:45:31)
# Step:   544 Model Time: 24.8 megayear dt: 170433.2 year (2020-02-19 05:45:55)
# Step:   545 Model Time: 25.0 megayear dt: 152792.6 year (2020-02-19 05:47:06)
# Step:   546 Model Time: 25.2 megayear dt: 168087.6 year (2020-02-19 05:47:29)
# Step:   547 Model Time: 25.3 megayear dt: 158714.3 year (2020-02-19 05:47:52)
# Step:   548 Model Time: 25.5 megayear dt: 149016.7 year (2020-02-19 05:48:16)
# Step:   549 Model Time: 25.5 megayear dt: 24181.4 year (2020-02-19 05:49:28)
# Step:   550 Model Time: 25.6 megayear dt: 149023.9 year (2020-02-19 05:49:51)
# Step:   551 Model Time: 25.8 megayear dt: 146557.8 year (2020-02-19 05:50:15)
# Step:   552 Model Time: 26.0 megayear dt: 160512.9 year (2020-02-19 05:50:38)
# Step:   553 Model Time: 26.0 megayear dt: 43905.4 year (2020-02-19 05:51:49)
# Step:   554 Model Time: 26.2 megayear dt: 170346.8 year (2020-02-19 05:52:12)
# Step:   555 Model Time: 26.3 megayear dt: 163799.6 year (2020-02-19 05:52:41)
# Step:   556 Model Time: 26.5 megayear dt: 162128.8 year (2020-02-19 05:53:05)
# Step:   557 Model Time: 26.5 megayear dt: 3724.8 year (2020-02-19 05:54:17)
# Step:   558 Model Time: 26.7 megayear dt: 161173.8 year (2020-02-19 05:54:41)
# Step:   559 Model Time: 26.8 megayear dt: 159823.2 year (2020-02-19 05:55:05)
# Step:   560 Model Time: 27.0 megayear dt: 158630.6 year (2020-02-19 05:55:28)
# Step:   561 Model Time: 27.0 megayear dt: 20372.4 year (2020-02-19 05:56:39)
# Step:   562 Model Time: 27.2 megayear dt: 160521.5 year (2020-02-19 05:57:02)
# Step:   563 Model Time: 27.3 megayear dt: 165225.0 year (2020-02-19 05:57:25)
# Step:   564 Model Time: 27.5 megayear dt: 159854.6 year (2020-02-19 05:57:48)
# Step:   565 Model Time: 27.5 megayear dt: 14398.8 year (2020-02-19 05:58:59)
# Step:   566 Model Time: 27.7 megayear dt: 159663.5 year (2020-02-19 05:59:22)
# Step:   567 Model Time: 27.8 megayear dt: 154541.6 year (2020-02-19 05:59:46)
# Step:   568 Model Time: 28.0 megayear dt: 164168.9 year (2020-02-19 06:00:09)
# Step:   569 Model Time: 28.0 megayear dt: 21626.0 year (2020-02-19 06:01:21)
# Step:   570 Model Time: 28.2 megayear dt: 156010.5 year (2020-02-19 06:01:44)
# Step:   571 Model Time: 28.3 megayear dt: 154016.7 year (2020-02-19 06:02:07)
# Step:   572 Model Time: 28.5 megayear dt: 157033.2 year (2020-02-19 06:02:30)
# Step:   573 Model Time: 28.5 megayear dt: 32939.6 year (2020-02-19 06:03:42)
# Step:   574 Model Time: 28.7 megayear dt: 160444.3 year (2020-02-19 06:04:06)
# Step:   575 Model Time: 28.8 megayear dt: 165521.5 year (2020-02-19 06:04:29)
# Step:   576 Model Time: 29.0 megayear dt: 165845.0 year (2020-02-19 06:04:52)
# Step:   577 Model Time: 29.0 megayear dt: 8189.2 year (2020-02-19 06:06:04)
# Step:   578 Model Time: 29.2 megayear dt: 173025.7 year (2020-02-19 06:06:27)
# Step:   579 Model Time: 29.4 megayear dt: 181013.5 year (2020-02-19 06:06:51)
# Step:   580 Model Time: 29.5 megayear dt: 145960.8 year (2020-02-19 06:08:05)
# Step:   581 Model Time: 29.7 megayear dt: 158510.3 year (2020-02-19 06:08:34)
# Step:   582 Model Time: 29.8 megayear dt: 164591.4 year (2020-02-19 06:08:57)
# Step:   583 Model Time: 30.0 megayear dt: 171405.1 year (2020-02-19 06:09:20)
# Step:   584 Model Time: 30.0 megayear dt: 5493.2 year (2020-02-19 06:10:31)
# Step:   585 Model Time: 30.2 megayear dt: 182888.5 year (2020-02-19 06:10:54)
# Step:   586 Model Time: 30.4 megayear dt: 190167.9 year (2020-02-19 06:11:18)
# Step:   587 Model Time: 30.5 megayear dt: 126943.5 year (2020-02-19 06:12:29)
# Step:   588 Model Time: 30.7 megayear dt: 169624.8 year (2020-02-19 06:12:52)
# Step:   589 Model Time: 30.8 megayear dt: 165856.8 year (2020-02-19 06:13:16)
# Step:   590 Model Time: 31.0 megayear dt: 164518.4 year (2020-02-19 06:14:28)
# Step:   591 Model Time: 31.2 megayear dt: 159820.5 year (2020-02-19 06:14:51)
# Step:   592 Model Time: 31.3 megayear dt: 184186.8 year (2020-02-19 06:15:20)
# Step:   593 Model Time: 31.5 megayear dt: 155992.7 year (2020-02-19 06:16:31)
# Step:   594 Model Time: 31.7 megayear dt: 190331.1 year (2020-02-19 06:16:54)
# Step:   595 Model Time: 31.9 megayear dt: 183175.9 year (2020-02-19 06:17:17)
# Step:   596 Model Time: 32.0 megayear dt: 126493.1 year (2020-02-19 06:18:34)
# Step:   597 Model Time: 32.2 megayear dt: 181030.6 year (2020-02-19 06:18:57)
# Step:   598 Model Time: 32.4 megayear dt: 175895.5 year (2020-02-19 06:19:21)
# Step:   599 Model Time: 32.5 megayear dt: 143073.8 year (2020-02-19 06:20:33)
# Step:   600 Model Time: 32.7 megayear dt: 173958.5 year (2020-02-19 06:20:57)
# Step:   601 Model Time: 32.8 megayear dt: 163919.8 year (2020-02-19 06:21:21)
# Step:   602 Model Time: 33.0 megayear dt: 162121.7 year (2020-02-19 06:22:32)
# Step:   603 Model Time: 33.2 megayear dt: 180869.1 year (2020-02-19 06:22:56)
# Step:   604 Model Time: 33.4 megayear dt: 171111.7 year (2020-02-19 06:23:19)
# Step:   605 Model Time: 33.5 megayear dt: 148019.2 year (2020-02-19 06:24:35)
# Step:   606 Model Time: 33.7 megayear dt: 164089.1 year (2020-02-19 06:24:59)
# Step:   607 Model Time: 33.9 megayear dt: 201690.2 year (2020-02-19 06:25:33)
# Step:   608 Model Time: 34.0 megayear dt: 134220.7 year (2020-02-19 06:26:45)
# Step:   609 Model Time: 34.2 megayear dt: 213246.4 year (2020-02-19 06:27:08)
# Step:   610 Model Time: 34.4 megayear dt: 210930.8 year (2020-02-19 06:27:31)
# Step:   611 Model Time: 34.5 megayear dt: 75822.8 year (2020-02-19 06:28:44)
# Step:   612 Model Time: 34.7 megayear dt: 198748.7 year (2020-02-19 06:29:07)
# Step:   613 Model Time: 34.9 megayear dt: 191249.2 year (2020-02-19 06:29:30)
# Step:   614 Model Time: 35.0 megayear dt: 110002.1 year (2020-02-19 06:30:53)
# Step:   615 Model Time: 35.2 megayear dt: 168436.2 year (2020-02-19 06:31:17)
# Step:   616 Model Time: 35.3 megayear dt: 176454.1 year (2020-02-19 06:31:40)
# Step:   617 Model Time: 35.5 megayear dt: 155109.7 year (2020-02-19 06:32:51)
# Step:   618 Model Time: 35.7 megayear dt: 168809.8 year (2020-02-19 06:33:20)
# Step:   619 Model Time: 35.9 megayear dt: 201827.7 year (2020-02-19 06:33:54)
# Step:   620 Model Time: 36.0 megayear dt: 129362.5 year (2020-02-19 06:35:04)
# Step:   621 Model Time: 36.2 megayear dt: 200659.1 year (2020-02-19 06:35:28)
# Step:   622 Model Time: 36.4 megayear dt: 192849.0 year (2020-02-19 06:35:51)
# Step:   623 Model Time: 36.5 megayear dt: 106491.8 year (2020-02-19 06:37:07)
# Step:   624 Model Time: 36.7 megayear dt: 184188.2 year (2020-02-19 06:37:31)
# ...
# Step:   629 Model Time: 37.5 megayear dt: 117357.5 year (2020-02-19 06:41:07)
# Step:   630 Model Time: 37.7 megayear dt: 211913.6 year (2020-02-19 06:41:30)
# Step:   631 Model Time: 37.9 megayear dt: 217260.5 year (2020-02-19 06:41:53)
# Step:   632 Model Time: 38.0 megayear dt: 70825.9 year (2020-02-19 06:43:11)
# Step:   633 Model Time: 38.2 megayear dt: 232800.8 year (2020-02-19 06:43:34)
# Step:   634 Model Time: 38.5 megayear dt: 226003.9 year (2020-02-19 06:43:57)
# Step:   635 Model Time: 38.5 megayear dt: 41195.3 year (2020-02-19 06:45:08)
# Step:   636 Model Time: 38.7 megayear dt: 226517.4 year (2020-02-19 06:45:31)
# Step:   637 Model Time: 39.0 megayear dt: 238405.3 year (2020-02-19 06:45:54)
# Step:   638 Model Time: 39.0 megayear dt: 35077.3 year (2020-02-19 06:47:17)
# Step:   639 Model Time: 39.2 megayear dt: 229492.7 year (2020-02-19 06:47:45)
# Step:   640 Model Time: 39.5 megayear dt: 265012.9 year (2020-02-19 06:48:13)
# Step:   641 Model Time: 39.5 megayear dt: 5494.5 year (2020-02-19 06:49:35)
# Step:   642 Model Time: 39.8 megayear dt: 318861.2 year (2020-02-19 06:49:58)
# Step:   643 Model Time: 40.0 megayear dt: 181138.8 year (2020-02-19 06:51:09)
# Step:   644 Model Time: 40.3 megayear dt: 317639.6 year (2020-02-19 06:51:32)
# Step:   645 Model Time: 40.5 megayear dt: 182360.4 year (2020-02-19 06:52:42)
# Step:   646 Model Time: 40.8 megayear dt: 312090.9 year (2020-02-19 06:53:05)
# Step:   647 Model Time: 41.0 megayear dt: 187909.1 year (2020-02-19 06:54:17)
# Step:   648 Model Time: 41.3 megayear dt: 310032.6 year (2020-02-19 06:54:40)
# Step:   649 Model Time: 41.5 megayear dt: 189967.4 year (2020-02-19 06:55:53)
# Step:   650 Model Time: 41.8 megayear dt: 320961.6 year (2020-02-19 06:56:21)
# Step:   651 Model Time: 42.0 megayear dt: 179038.4 year (2020-02-19 06:57:32)
# Step:   652 Model Time: 42.3 megayear dt: 287472.8 year (2020-02-19 06:58:00)
# Step:   653 Model Time: 42.5 megayear dt: 212527.2 year (2020-02-19 06:59:11)
# Step:   654 Model Time: 42.8 megayear dt: 312639.6 year (2020-02-19 06:59:45)
# Step:   655 Model Time: 43.0 megayear dt: 187360.4 year (2020-02-19 07:00:58)
# Step:   656 Model Time: 43.3 megayear dt: 327701.9 year (2020-02-19 07:01:21)
# Step:   657 Model Time: 43.5 megayear dt: 172298.1 year (2020-02-19 07:02:44)
# Step:   658 Model Time: 43.9 megayear dt: 356529.9 year (2020-02-19 07:03:07)
# Step:   659 Model Time: 44.0 megayear dt: 143470.1 year (2020-02-19 07:04:22)
# Step:   660 Model Time: 44.4 megayear dt: 388938.0 year (2020-02-19 07:04:45)
# Step:   661 Model Time: 44.5 megayear dt: 111062.0 year (2020-02-19 07:05:57)
# Step:   662 Model Time: 45.0 megayear dt: 456492.2 year (2020-02-19 07:06:20)
# Step:   663 Model Time: 45.0 megayear dt: 43507.8 year (2020-02-19 07:07:35)
# Step:   664 Model Time: 45.5 megayear dt: 478389.2 year (2020-02-19 07:07:58)
# Step:   665 Model Time: 45.5 megayear dt: 21610.8 year (2020-02-19 07:09:09)
# Step:   666 Model Time: 46.0 megayear dt: 458335.5 year (2020-02-19 07:09:32)
# Step:   667 Model Time: 46.0 megayear dt: 41664.5 year (2020-02-19 07:10:48)
# Step:   668 Model Time: 46.4 megayear dt: 396811.4 year (2020-02-19 07:11:11)
# Step:   669 Model Time: 46.5 megayear dt: 103188.6 year (2020-02-19 07:12:21)
# Step:   670 Model Time: 46.9 megayear dt: 423880.4 year (2020-02-19 07:12:44)
# Step:   671 Model Time: 47.0 megayear dt: 76119.6 year (2020-02-19 07:13:55)
# Step:   672 Model Time: 47.4 megayear dt: 384551.7 year (2020-02-19 07:14:19)
# Step:   673 Model Time: 47.5 megayear dt: 115448.3 year (2020-02-19 07:15:30)
# Step:   674 Model Time: 47.9 megayear dt: 382476.1 year (2020-02-19 07:15:53)
# Step:   675 Model Time: 48.0 megayear dt: 117523.9 year (2020-02-19 07:17:15)
# Step:   676 Model Time: 48.4 megayear dt: 420274.0 year (2020-02-19 07:17:39)
# Step:   677 Model Time: 48.5 megayear dt: 79726.0 year (2020-02-19 07:19:02)
# Step:   678 Model Time: 48.9 megayear dt: 427566.8 year (2020-02-19 07:19:25)
# Step:   679 Model Time: 49.0 megayear dt: 72433.2 year (2020-02-19 07:20:57)
# Step:   680 Model Time: 49.5 megayear dt: 500000.0 year (2020-02-19 07:22:08)
# Step:   681 Model Time: 50.0 megayear dt: 500000.0 year (2020-02-19 07:23:26)
# Step:   682 Model Time: 50.5 megayear dt: 500000.0 year (2020-02-19 07:24:48)
# Step:   683 Model Time: 51.0 megayear dt: 495832.0 year (2020-02-19 07:25:17)
# Step:   684 Model Time: 51.0 megayear dt: 4168.0 year (2020-02-19 07:26:45)
# Step:   685 Model Time: 51.5 megayear dt: 450396.0 year (2020-02-19 07:27:08)
# Step:   686 Model Time: 51.5 megayear dt: 49604.0 year (2020-02-19 07:28:19)
# Step:   687 Model Time: 51.9 megayear dt: 433221.7 year (2020-02-19 07:28:42)
# Step:   688 Model Time: 52.0 megayear dt: 66778.3 year (2020-02-19 07:29:53)
# Step:   689 Model Time: 52.4 megayear dt: 396396.4 year (2020-02-19 07:30:17)
# Step:   690 Model Time: 52.5 megayear dt: 103603.6 year (2020-02-19 07:31:29)
# Step:   691 Model Time: 52.9 megayear dt: 408209.8 year (2020-02-19 07:31:52)
# Step:   692 Model Time: 53.0 megayear dt: 91790.2 year (2020-02-19 07:33:09)
# Step:   693 Model Time: 53.4 megayear dt: 408115.9 year (2020-02-19 07:33:33)
# Step:   694 Model Time: 53.5 megayear dt: 91884.1 year (2020-02-19 07:35:00)
# Step:   695 Model Time: 53.9 megayear dt: 434399.9 year (2020-02-19 07:35:23)
# Step:   696 Model Time: 54.0 megayear dt: 65600.1 year (2020-02-19 07:36:35)
# Step:   697 Model Time: 54.4 megayear dt: 441055.8 year (2020-02-19 07:36:58)
# Step:   698 Model Time: 54.5 megayear dt: 58944.2 year (2020-02-19 07:38:11)
# Step:   699 Model Time: 55.0 megayear dt: 500000.0 year (2020-02-19 07:39:50)
# Step:   700 Model Time: 55.5 megayear dt: 456535.5 year (2020-02-19 07:40:18)
# Step:   701 Model Time: 55.5 megayear dt: 43464.5 year (2020-02-19 07:41:34)
# Step:   702 Model Time: 55.9 megayear dt: 428044.8 year (2020-02-19 07:41:58)
# Step:   703 Model Time: 56.0 megayear dt: 71955.2 year (2020-02-19 07:43:09)
# Step:   704 Model Time: 56.4 megayear dt: 448790.4 year (2020-02-19 07:43:32)
# Step:   705 Model Time: 56.5 megayear dt: 51209.6 year (2020-02-19 07:44:45)
# Step:   706 Model Time: 57.0 megayear dt: 453275.9 year (2020-02-19 07:45:08)
# Step:   707 Model Time: 57.0 megayear dt: 46724.1 year (2020-02-19 07:46:24)
# Step:   708 Model Time: 57.5 megayear dt: 469752.5 year (2020-02-19 07:46:48)
# Step:   709 Model Time: 57.5 megayear dt: 30247.5 year (2020-02-19 07:48:14)
# Step:   710 Model Time: 57.8 megayear dt: 326003.5 year (2020-02-19 07:48:37)
# Step:   711 Model Time: 58.0 megayear dt: 173996.5 year (2020-02-19 07:49:54)
# Step:   712 Model Time: 58.4 megayear dt: 353183.5 year (2020-02-19 07:50:17)
# Step:   713 Model Time: 58.5 megayear dt: 146816.5 year (2020-02-19 07:51:33)
# Step:   714 Model Time: 58.9 megayear dt: 428159.7 year (2020-02-19 07:52:02)
# Step:   715 Model Time: 59.0 megayear dt: 71840.3 year (2020-02-19 07:53:17)
# Step:   716 Model Time: 59.4 megayear dt: 356349.5 year (2020-02-19 07:53:41)
# Step:   717 Model Time: 59.5 megayear dt: 143650.5 year (2020-02-19 07:54:53)
# Step:   718 Model Time: 59.9 megayear dt: 374818.9 year (2020-02-19 07:55:23)
# Step:   719 Model Time: 60.0 megayear dt: 125181.1 year (2020-02-19 07:56:39)
# Step:   720 Model Time: 60.5 megayear dt: 468340.5 year (2020-02-19 07:57:14)
# Step:   721 Model Time: 60.5 megayear dt: 31659.5 year (2020-02-19 07:58:36)
# Step:   722 Model Time: 60.9 megayear dt: 419239.0 year (2020-02-19 07:59:05)
# Step:   723 Model Time: 61.0 megayear dt: 80761.0 year (2020-02-19 08:00:28)
# Step:   724 Model Time: 61.5 megayear dt: 500000.0 year (2020-02-19 08:01:39)
# Step:   725 Model Time: 61.9 megayear dt: 390547.3 year (2020-02-19 08:02:13)
# Step:   726 Model Time: 62.0 megayear dt: 109452.7 year (2020-02-19 08:03:26)
# Step:   727 Model Time: 62.4 megayear dt: 403587.0 year (2020-02-19 08:03:49)
# Step:   728 Model Time: 62.5 megayear dt: 96413.0 year (2020-02-19 08:05:02)
# Step:   729 Model Time: 62.9 megayear dt: 378919.9 year (2020-02-19 08:05:26)
# Step:   730 Model Time: 63.0 megayear dt: 121080.1 year (2020-02-19 08:06:42)
# Step:   731 Model Time: 63.4 megayear dt: 416649.9 year (2020-02-19 08:07:06)
# Step:   732 Model Time: 63.5 megayear dt: 83350.1 year (2020-02-19 08:08:17)
# Step:   733 Model Time: 63.9 megayear dt: 388102.5 year (2020-02-19 08:08:40)
# Step:   734 Model Time: 64.0 megayear dt: 111897.5 year (2020-02-19 08:10:02)
# Step:   735 Model Time: 64.4 megayear dt: 360392.5 year (2020-02-19 08:10:25)
# Step:   736 Model Time: 64.5 megayear dt: 139607.5 year (2020-02-19 08:11:41)
# Step:   737 Model Time: 64.8 megayear dt: 301522.3 year (2020-02-19 08:12:10)
# Step:   738 Model Time: 65.0 megayear dt: 198477.7 year (2020-02-19 08:13:32)
# Step:   739 Model Time: 65.3 megayear dt: 337123.0 year (2020-02-19 08:14:01)
# Step:   740 Model Time: 65.5 megayear dt: 162877.0 year (2020-02-19 08:15:22)
# Step:   741 Model Time: 65.8 megayear dt: 272415.9 year (2020-02-19 08:15:56)
# Step:   742 Model Time: 66.0 megayear dt: 227584.1 year (2020-02-19 08:17:13)
# Step:   743 Model Time: 66.3 megayear dt: 270765.9 year (2020-02-19 08:17:37)
# Step:   744 Model Time: 66.5 megayear dt: 229234.1 year (2020-02-19 08:18:49)
# Step:   745 Model Time: 66.8 megayear dt: 260015.8 year (2020-02-19 08:19:13)
# Step:   746 Model Time: 67.0 megayear dt: 239984.2 year (2020-02-19 08:20:36)
# Step:   747 Model Time: 67.3 megayear dt: 300629.6 year (2020-02-19 08:20:59)
# Step:   748 Model Time: 67.5 megayear dt: 199370.4 year (2020-02-19 08:22:31)
# Step:   749 Model Time: 67.8 megayear dt: 325843.9 year (2020-02-19 08:22:54)
# Step:   750 Model Time: 68.0 megayear dt: 174156.1 year (2020-02-19 08:24:06)
# Step:   751 Model Time: 68.3 megayear dt: 340200.3 year (2020-02-19 08:24:30)
# Step:   752 Model Time: 68.5 megayear dt: 159799.7 year (2020-02-19 08:25:48)
# Step:   753 Model Time: 68.8 megayear dt: 295569.9 year (2020-02-19 08:26:22)
# Step:   754 Model Time: 69.0 megayear dt: 204430.1 year (2020-02-19 08:27:33)
# Step:   755 Model Time: 69.3 megayear dt: 299651.4 year (2020-02-19 08:27:56)
# Step:   756 Model Time: 69.5 megayear dt: 200348.6 year (2020-02-19 08:29:07)
# Step:   757 Model Time: 69.8 megayear dt: 269534.0 year (2020-02-19 08:29:51)
# Step:   758 Model Time: 70.0 megayear dt: 230466.0 year (2020-02-19 08:31:02)
# Step:   759 Model Time: 70.3 megayear dt: 259889.8 year (2020-02-19 08:31:25)
# Step:   760 Model Time: 70.5 megayear dt: 240110.2 year (2020-02-19 08:32:36)
# Step:   761 Model Time: 70.8 megayear dt: 256350.5 year (2020-02-19 08:32:59)
# Step:   762 Model Time: 71.0 megayear dt: 243649.5 year (2020-02-19 08:34:11)
# Step:   763 Model Time: 71.3 megayear dt: 306239.1 year (2020-02-19 08:34:51)
# Step:   764 Model Time: 71.5 megayear dt: 193760.9 year (2020-02-19 08:36:08)
# Step:   765 Model Time: 71.8 megayear dt: 257841.3 year (2020-02-19 08:36:31)
# Step:   766 Model Time: 72.0 megayear dt: 242158.7 year (2020-02-19 08:37:47)
# Step:   767 Model Time: 72.3 megayear dt: 326214.5 year (2020-02-19 08:38:11)
# Step:   768 Model Time: 72.5 megayear dt: 173785.5 year (2020-02-19 08:39:27)
# Step:   769 Model Time: 72.9 megayear dt: 386968.8 year (2020-02-19 08:39:56)
# Step:   770 Model Time: 73.0 megayear dt: 113031.2 year (2020-02-19 08:41:14)
# Step:   771 Model Time: 73.4 megayear dt: 353550.1 year (2020-02-19 08:41:37)
# Step:   772 Model Time: 73.5 megayear dt: 146449.9 year (2020-02-19 08:42:54)
# Step:   773 Model Time: 73.8 megayear dt: 326606.0 year (2020-02-19 08:43:18)
# Step:   774 Model Time: 74.0 megayear dt: 173394.0 year (2020-02-19 08:44:29)
# Step:   775 Model Time: 74.4 megayear dt: 361693.1 year (2020-02-19 08:44:52)
# Step:   776 Model Time: 74.5 megayear dt: 138306.9 year (2020-02-19 08:46:24)
# Step:   777 Model Time: 75.0 megayear dt: 451057.0 year (2020-02-19 08:46:47)
# Step:   778 Model Time: 75.0 megayear dt: 48943.0 year (2020-02-19 08:48:04)
# Step:   779 Model Time: 75.4 megayear dt: 434582.2 year (2020-02-19 08:48:28)
# Step:   780 Model Time: 75.5 megayear dt: 65417.8 year (2020-02-19 08:49:40)
# Step:   781 Model Time: 75.9 megayear dt: 401620.9 year (2020-02-19 08:50:11)
# Step:   782 Model Time: 76.0 megayear dt: 98379.1 year (2020-02-19 08:51:23)
# Step:   783 Model Time: 76.5 megayear dt: 463597.8 year (2020-02-19 08:51:47)
# Step:   784 Model Time: 76.5 megayear dt: 36402.2 year (2020-02-19 08:53:04)
# Step:   785 Model Time: 76.9 megayear dt: 422808.5 year (2020-02-19 08:53:28)
# Step:   786 Model Time: 77.0 megayear dt: 77191.5 year (2020-02-19 08:54:42)
# Step:   787 Model Time: 77.5 megayear dt: 468900.2 year (2020-02-19 08:55:05)
# Step:   788 Model Time: 77.5 megayear dt: 31099.8 year (2020-02-19 08:56:22)
# Step:   789 Model Time: 78.0 megayear dt: 500000.0 year (2020-02-19 08:57:34)
# Step:   790 Model Time: 78.5 megayear dt: 500000.0 year (2020-02-19 08:58:45)
# Step:   791 Model Time: 79.0 megayear dt: 500000.0 year (2020-02-19 09:00:07)
# Step:   792 Model Time: 79.5 megayear dt: 500000.0 year (2020-02-19 09:01:18)
# Step:   793 Model Time: 80.0 megayear dt: 500000.0 year (2020-02-19 09:02:41)
# Step:   794 Model Time: 80.5 megayear dt: 500000.0 year (2020-02-19 09:03:53)
# Step:   795 Model Time: 81.0 megayear dt: 500000.0 year (2020-02-19 09:05:15)
# Step:   796 Model Time: 81.5 megayear dt: 500000.0 year (2020-02-19 09:06:37)
# Step:   797 Model Time: 82.0 megayear dt: 500000.0 year (2020-02-19 09:07:54)
# Step:   798 Model Time: 82.5 megayear dt: 500000.0 year (2020-02-19 09:09:11)
# Step:   799 Model Time: 83.0 megayear dt: 500000.0 year (2020-02-19 09:10:24)
# Step:   800 Model Time: 83.5 megayear dt: 500000.0 year (2020-02-19 09:11:37)
# Step:   801 Model Time: 84.0 megayear dt: 500000.0 year (2020-02-19 09:12:55)
# Step:   802 Model Time: 84.5 megayear dt: 500000.0 year (2020-02-19 09:14:23)
# Step:   803 Model Time: 85.0 megayear dt: 500000.0 year (2020-02-19 09:15:34)
# Step:   804 Model Time: 85.5 megayear dt: 500000.0 year (2020-02-19 09:16:52)
# Step:   805 Model Time: 86.0 megayear dt: 500000.0 year (2020-02-19 09:18:03)
# Step:   806 Model Time: 86.5 megayear dt: 500000.0 year (2020-02-19 09:19:19)
# Step:   807 Model Time: 87.0 megayear dt: 500000.0 year (2020-02-19 09:20:35)
# Step:   808 Model Time: 87.5 megayear dt: 500000.0 year (2020-02-19 09:21:47)
# Step:   809 Model Time: 88.0 megayear dt: 500000.0 year (2020-02-19 09:23:00)
# Step:   810 Model Time: 88.5 megayear dt: 500000.0 year (2020-02-19 09:24:21)
# Step:   811 Model Time: 89.0 megayear dt: 500000.0 year (2020-02-19 09:25:40)
# Step:   812 Model Time: 89.5 megayear dt: 500000.0 year (2020-02-19 09:26:52)
# Step:   813 Model Time: 90.0 megayear dt: 500000.0 year (2020-02-19 09:28:09)
# Step:   814 Model Time: 90.5 megayear dt: 500000.0 year (2020-02-19 09:29:20)
# Step:   815 Model Time: 91.0 megayear dt: 500000.0 year (2020-02-19 09:30:31)
# Step:   816 Model Time: 91.5 megayear dt: 500000.0 year (2020-02-19 09:31:43)
# Step:   817 Model Time: 92.0 megayear dt: 500000.0 year (2020-02-19 09:32:56)
# Step:   818 Model Time: 92.5 megayear dt: 500000.0 year (2020-02-19 09:34:19)
# Step:   819 Model Time: 93.0 megayear dt: 500000.0 year (2020-02-19 09:35:47)
# Step:   820 Model Time: 93.5 megayear dt: 500000.0 year (2020-02-19 09:36:59)
# Step:   821 Model Time: 94.0 megayear dt: 500000.0 year (2020-02-19 09:38:10)
# Step:   822 Model Time: 94.5 megayear dt: 500000.0 year (2020-02-19 09:39:21)
# Step:   823 Model Time: 95.0 megayear dt: 500000.0 year (2020-02-19 09:40:34)
# Step:   824 Model Time: 95.5 megayear dt: 500000.0 year (2020-02-19 09:42:01)
# Step:   825 Model Time: 96.0 megayear dt: 500000.0 year (2020-02-19 09:43:25)
# Step:   826 Model Time: 96.5 megayear dt: 500000.0 year (2020-02-19 09:44:42)
# Step:   827 Model Time: 97.0 megayear dt: 500000.0 year (2020-02-19 09:46:00)
# Step:   828 Model Time: 97.5 megayear dt: 500000.0 year (2020-02-19 09:47:17)
# Step:   829 Model Time: 98.0 megayear dt: 500000.0 year (2020-02-19 09:48:34)
# Step:   830 Model Time: 98.5 megayear dt: 500000.0 year (2020-02-19 09:49:45)
# Step:   831 Model Time: 99.0 megayear dt: 500000.0 year (2020-02-19 09:50:59)
# Step:   832 Model Time: 99.5 megayear dt: 500000.0 year (2020-02-19 09:52:12)
# Step:   833 Model Time: 100.0 megayear dt: 500000.0 year (2020-02-19 09:52:35)
# 1

# %%
#Preview of 2D materials-Materials Field (from swarm)
Fig = glucifer.Figure(figsize=(1200,400))
Fig.Points(Model.swarm, Model.materialField,fn_size=2.0, discrete=True)
#Fig.Surface(Model.mesh,Model.projMaterialField,fn_size=2.0)
Fig.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
#Preview of 2D materials-Materials Field (from swarm)
Fig = glucifer.Figure(figsize=(1200,400))
#Fig.Points(Model.swarm, Model.materialField,fn_size=2.0, discrete=True)
Fig.Surface(Model.mesh,Model.projMaterialField,fn_size=2.0)
Fig.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
Fig = glucifer.Figure(figsize=(1200,400))
Fig.Points(Model.swarm, GEO.Dimensionalize(Model.viscosityField, u.pascal * u.second),logScale=True)
Fig.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
Fig = glucifer.Figure(figsize=(1200,400))
Fig.Points(Model.swarm, GEO.Dimensionalize(Model.densityField, u.kilogram / u.metre**3))
#Fig.Surface(Model.mesh, GEO.Dimensionalize(Model.projDensityField, u.kilogram / u.metre**3))
Fig.show()
# Out:
# <img src='data:image/png;base64,...'>
